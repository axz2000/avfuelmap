# %%
import pandas as pd

# %%
airports = pd.read_json("airports.json",orient='index')

# %%
airports.head()
# Out:
#               city country  elevation iata  icao        lat         lon  \
# 00AK  Anchor Point      US        450       00AK  59.949200 -151.695999
# 00AL       Harvest      US        820       00AL  34.864799  -86.770302
# 00AZ        Cordes      US       3810       00AZ  34.305599 -112.165001
# 00CA       Barstow      US       3038       00CA  35.350498 -116.888000
# 00CO    Briggsdale      US       4830       00CO  40.622200 -104.344002
#
#                          name       state                   tz
# 00AK             Lowell Field      Alaska    America/Anchorage
# 00AL             Epps Airpark     Alabama      America/Chicago
# 00AZ           Cordes Airport     Arizona      America/Phoenix
# 00CA  Goldstone /Gts/ Airport  California  America/Los_Angeles
# 00CO               Cass Field    Colorado       America/Denver

# %%
airports = airports[airports['country'].isin(['US','CA'])]
airports = airports.drop(columns=['country','elevation','iata','tz'])
airports
# Out:
#               city  icao        lat         lon                      name  \
# 00AK  Anchor Point  00AK  59.949200 -151.695999              Lowell Field
# 00AL       Harvest  00AL  34.864799  -86.770302              Epps Airpark
# 00AZ        Cordes  00AZ  34.305599 -112.165001            Cordes Airport
# 00CA       Barstow  00CA  35.350498 -116.888000   Goldstone /Gts/ Airport
# 00CO    Briggsdale  00CO  40.622200 -104.344002                Cass Field
# ...            ...   ...        ...         ...                       ...
# XS92      Paradise  XS92  33.146000  -97.712502    Jackson /Bill/ Airport
# XS93   Santa Elena  XS93  26.716999  -98.558601   Diamond O Ranch Airport
# XS94   San Ygnacio  XS94  27.111401  -99.422501        Corralitos Airport
# XS95   Schulenburg  XS95  29.676901  -96.970497       Marty Ranch Airport
# XS99      Shepherd  XS99  30.471001  -94.912697  Lake Water Wheel Airport
#
#            state
# 00AK      Alaska
# 00AL     Alabama
# 00AZ     Arizona
# 00CA  California
# 00CO    Colorado
# ...          ...
# XS92       Texas
# XS93       Texas
# XS94       Texas
# XS95       Texas
# XS99       Texas
#
# [14463 rows x 6 columns]

# %%
airports.to_json('USCAairports.json',orient='index')

# %%
import requests as r
from bs4 import BeautifulSoup as bs

# %%
url="https://www.airnav.com/airport/00AK"

# %%
response = r.get(url)
response.status_code
# Out:
# 200

# %%
soup = bs(response.text, 'html.parser')
tables = soup.find_all("td", width=94)
minLL = 100
minJA = 100
for a in tables:
    rows = a.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [element.text.strip() for element in cols]
        clean = [x for x in cols if x]
        print(clean)
        if len(clean)==3:
            if clean[0]=='FS' or clean[0]=='SS':
                LL = float(clean[1][1:])
                JA = float(clean[2][1:])
                print(LL,JA)
                if LL<minLL:
                    minLL=LL
                if JA<minJA:
                    minJA=JA
strLL = str(minLL)
strJA = str(minJA)
if len(strLL)==3:
    strLL = strLL+'0'
if len(strJA)==3:
    strJA = strJA+'0'
# Out:
# 100 100
# 1000 1000

# %%
#100LL will be index 1, JetA index 2
#param: icao code
#returns strLL, strJA

def get_min_price(airport):
    url="https://www.airnav.com/airport/"+airport
    response = r.get(url)
    soup = bs(response.text, 'html.parser')
    tables = soup.find_all("td", width=94)
    minLL = 100
    minJA = 100
    for a in tables:
        rows = a.find_all('tr')
        for row in rows:
            cols = row.find_all('td')
            cols = [element.text.strip() for element in cols]
            clean = [x for x in cols if x]
            if len(clean)==3:
                if clean[0]=='FS' or clean[0]=='SS':
                    if clean[1][1:]=='--':
                        LL=100
                    else:
                        LL = float(clean[1][1:])
                    if clean[2][1:]=='--':
                        JA=100
                    else:
                        JA = float(clean[2][1:])
                    if LL<minLL:
                        minLL=LL
                    if JA<minJA:
                        minJA=JA
    strLL = str(minLL)
    strJA = str(minJA)
    if len(strLL)==3:
        strLL = strLL+'0'
    if len(strJA)==3:
        strJA = strJA+'0'
        
    return strLL,strJA,response.status_code

# %%
get_min_price('KTEB')
# Out:
# ('5.70', '3.89', 200)

# %%
import time

LLlist = []
JAlist = []
count=1
for airport in airports['icao']:
    time.sleep(5)
    results = get_min_price(airport)
    LLlist.append(results[0])
    JAlist.append(results[1])
    print('Done:',airport,results,count)
    count+=1
    
print(len(LLlist),len(JAlist))
# Out:
# Done: 00AK ('1000', '1000', 200) 1
# Done: 00AL ('1000', '1000', 200) 2
# Done: 00AZ ('1000', '1000', 200) 3
# Done: 00CA ('1000', '1000', 200) 4
# Done: 00CO ('1000', '1000', 200) 5
# Done: 00FA ('1000', '1000', 200) 6
# Done: 00FL ('1000', '1000', 200) 7
# Done: 00GA ('1000', '1000', 200) 8
# Done: 00ID ('1000', '1000', 200) 9
# Done: 00IL ('1000', '1000', 200) 10
# Done: 00IS ('1000', '1000', 200) 11
# Done: 00KS ('1000', '1000', 200) 12
# Done: 00KY ('1000', '1000', 200) 13
# Done: 00LS ('1000', '1000', 200) 14
# Done: 00MD ('1000', '1000', 200) 15
# Done: 00MN ('1000', '1000', 200) 16
# Done: 00MO ('1000', '1000', 200) 17
# Done: 00MT ('1000', '1000', 200) 18
# Done: 00NC ('1000', '1000', 200) 19
# Done: 00NY ('1000', '1000', 200) 20
# Done: 00OH ('1000', '1000', 200) 21
# Done: 00PN ('1000', '1000', 200) 22
# Done: 00PS ('1000', '1000', 200) 23
# Done: 00SC ('1000', '1000', 200) 24
# Done: 00TN ('1000', '1000', 200) 25
# Done: 00TS ('1000', '1000', 200) 26
# Done: 00VA ('1000', '1000', 200) 27
# Done: 00VI ('1000', '1000', 200) 28
# Done: 00WA ('1000', '1000', 200) 29
# Done: 00WI ('1000', '1000', 200) 30
# Done: 00WN ('1000', '1000', 200) 31
# Done: 00WV ('1000', '1000', 200) 32
# Done: 00XS ('1000', '1000', 200) 33
# Done: 01AL ('1000', '1000', 200) 34
# Done: 01CL ('1000', '1000', 200) 35
# Done: 01FA ('1000', '1000', 200) 36
# Done: 01FL ('1000', '1000', 200) 37
# Done: 01GE ('1000', '1000', 200) 38
# Done: 01IA ('1000', '1000', 200) 39
# Done: 01ID ('1000', '1000', 200) 40
# Done: 01II ('1000', '1000', 200) 41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-1b2596dfd12c> in <module>
#       5 count=1
#       6 for airport in airports['icao']:
# ----> 7     time.sleep(5)
#       8     results = get_min_price(airport)
#       9     LLlist.append(results[0])
#
# KeyboardInterrupt:

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

def get_airports(state):
    url='https://www.airnav.com/airports/us/'+state
    response = r.get(url)
    soup = bs(response.text, 'html.parser')
    tables = soup.find_all("td")
    names = []
    for a in tables:
        rows = a.find_all('a')
        if rows:
            names.append(rows[0])
    names1 = [element.text.strip() for element in names]
    return names1[5:-2]

# %%
airport_dict = {}
for state in states:
    time.sleep(5)
    airport_dict[state] = get_airports(state)
    print('Done:',state)
airport_dict
# Out:
# Done: AL
# Done: AK
# Done: AZ
# Done: AR
# Done: CA
# Done: CO
# Done: CT
# Done: DC
# Done: DE
# Done: FL
# Done: GA
# Done: HI
# Done: ID
# Done: IL
# Done: IN
# Done: IA
# Done: KS
# Done: KY
# Done: LA
# Done: ME
# Done: MD
# Done: MA
# Done: MI
# Done: MN
# Done: MS
# Done: MO
# Done: MT
# Done: NE
# Done: NV
# Done: NH
# Done: NJ
# Done: NM
# Done: NY
# Done: NC
# Done: ND
# Done: OH
# Done: OK
# Done: OR
# Done: PA
# Done: RI
# Done: SC
# Done: SD
# Done: TN
# Done: TX
# Done: UT
# Done: VT
# Done: VA
# Done: WA
# Done: WV
# Done: WI
# Done: WY
# {'AL': ['0J0',
#   '2A8',
#   'KEET',
#   '8A0',
#   'KALX',
#   'KAIV',
#   '79J',
#   'KANB',
#   '1M3',
#   '26A',
#   '0R1',
#   'KAUO',
#   '1R8',
#   '5R7',
#   'KEKY',
#   'KBHM',
#   '12J',
#   '09A',
#   '61A',
#   'KPYP',
#   '0A8',
#   '5R1',
#   '02A',
#   '11A',
#   '9A4',
#   '15A',
#   'KCMD',
#   '4R9',
#   'KDCU',
#   'KDYA',
#   'KDHN',
#   '3M2',
#   '14J',
#   'KEDN',
#   'KEUF',
#   'KGZH',
#   'KCQF',
#   'M95',
#   '0J4',
#   '5R4',
#   '4A9',
#   'KGAD',
#   '33J',
#   '7A0',
#   'KPRN',
#   'KJKA',
#   '8A1',
#   '1M4',
#   'KHAB',
#   '5M0',
#   'M38',
#   '0J6',
#   'KHSV',
#   'KMDQ',
#   '3M5',
#   '4R3',
#   'KJFX',
#   '7A3',
#   '04A',
#   'A08',
#   'KMOB',
#   'KBFM',
#   'KMVC',
#   'KMGM',
#   'KMSL',
#   '20A',
#   '71J',
#   'KPLR',
#   '1A9',
#   '3M8',
#   '7A5',
#   'M22',
#   '1A4',
#   '4A6',
#   'KSEM',
#   '2R5',
#   '7A6',
#   'KSCD',
#   'KASN',
#   'KTOI',
#   'KTCL',
#   '06A',
#   '07A',
#   'M55',
#   '08A'],
#  'AK': ['PADK',
#   'PAKH',
#   'Z13',
#   'PFAK',
#   'PAUT',
#   'PAUK',
#   '5A8',
#   'Z25',
#   'PFAL',
#   'PAFM',
#   '80A',
#   'PAKP',
#   'PANC',
#   'PAMR',
#   'PALH',
#   'A13',
#   'PANI',
#   'PANV',
#   'PARC',
#   'PAAK',
#   '4A2',
#   'PATQ',
#   'PABR',
#   'PABA',
#   'Z47',
#   'Z48',
#   'Z52',
#   'PAWB',
#   'PABE',
#   'PABT',
#   'PAGQ',
#   'Z91',
#   'PABV',
#   '5BK',
#   'BYA',
#   'PFKT',
#   'PABL',
#   'PATW',
#   'PACE',
#   'PACI',
#   '5CD',
#   'PALR',
#   'PACK',
#   'PFCB',
#   'PAVA',
#   'CKX',
#   'PAJC',
#   'KCL',
#   'A79',
#   'CZN',
#   'CZO',
#   'CXC',
#   'PACH',
#   'PACR',
#   'CHP',
#   'PFCL',
#   'PACL',
#   'CLF',
#   'PACD',
#   'PACX',
#   'JLA',
#   'Z93',
#   'CKU',
#   'PACV',
#   'K29',
#   'PACJ',
#   'DCK',
#   'PASC',
#   'PADE',
#   'D66',
#   'PADL',
#   'PAEG',
#   'PAEE',
#   'PAII',
#   'KEK',
#   'PFEL',
#   'PAEM',
#   '2Z2',
#   '2Z3',
#   'PAFA',
#   'PAAN',
#   'PAKF',
#   'PAFL',
#   '3Z1',
#   'FLT',
#   'PFYU',
#   'PAGB',
#   'PAGA',
#   'PAGM',
#   'AQY',
#   'KGZ',
#   'PAGL',
#   'GNU',
#   'Z40',
#   'PAGX',
#   'PAGK',
#   'PAGS',
#   'PAHN',
#   'PAHV',
#   'PAHC',
#   'PAHO',
#   'PAOH',
#   'PAHP',
#   '5HO',
#   '4Z5',
#   'PAHU',
#   'PAHL',
#   'PAIG',
#   'PAIL',
#   '4Z9',
#   'PAJN',
#   'PAFE',
#   'PALG',
#   'PAKV',
#   '5Z5',
#   'Z90',
#   'PAKY',
#   'PFKA',
#   '5KS',
#   'RK1',
#   'PAEN',
#   'PAKT',
#   'PAIK',
#   'PAVC',
#   'PAKN',
#   'PAKI',
#   'PAVL',
#   'PAKW',
#   'PAOB',
#   'PADQ',
#   'PAKD',
#   'PFKK',
#   'PAJZ',
#   'PADY',
#   'PFKO',
#   'PAOT',
#   'PAKK',
#   'PFKU',
#   'PAKL',
#   'PFKW',
#   'PAGG',
#   'Z55',
#   'PALB',
#   '9Z9',
#   '9Z8',
#   '2AK',
#   '4AK',
#   'PAML',
#   'PAMB',
#   'PADM',
#   'MYK',
#   'PAMX',
#   'AK0',
#   'PAMC',
#   'PAIN',
#   'PAMY',
#   'PFME',
#   'PAMD',
#   'PAMH',
#   '51Z',
#   'PAMO',
#   '76Z',
#   '5NK',
#   'KEB',
#   'PANA',
#   'PAPK',
#   'PAOU',
#   'PANN',
#   'PANW',
#   'PAEW',
#   'PAGT',
#   'PAFS',
#   'PAKO',
#   'NIN',
#   'PAWN',
#   'PAOM',
#   '94Z',
#   'PANO',
#   'PFNO',
#   '95Z',
#   'PAOR',
#   'PAQT',
#   'PANU',
#   'SXP',
#   'PPIT',
#   '6R7',
#   'Z17',
#   '4K5',
#   'PAAQ',
#   'AK1',
#   'PAXK',
#   '4K0',
#   'PAPE',
#   'PAPG',
#   'PAPN',
#   'UGB',
#   '0AK',
#   'PAPM',
#   'PAPO',
#   'PPIZ',
#   'PAKX',
#   'PGM',
#   'PAPH',
#   'ORI',
#   'PAOC',
#   'PAPR',
#   '01A',
#   '20K',
#   '5QC',
#   'PAQH',
#   '6AK',
#   'RMP',
#   'RDV',
#   'PARY',
#   'PARS',
#   'Z81',
#   'PASD',
#   'PASA',
#   'PACM',
#   'PASK',
#   'PASO',
#   'PAWD',
#   'PAHX',
#   'PFSH',
#   'PASP',
#   'PASH',
#   'PAGH',
#   'PASI',
#   'PAGY',
#   'PASW',
#   'PASL',
#   'PASX',
#   'PFWS',
#   'PAPB',
#   'PASM',
#   'PAMK',
#   'PASN',
#   'WBB',
#   'SVS',
#   'SRV',
#   'PAST',
#   'PPCT',
#   'PATK',
#   'TSG',
#   'PATA',
#   'PAKA',
#   '8KA',
#   'PATM',
#   'Z14',
#   '2K5',
#   'PATE',
#   '3T4',
#   'PATG',
#   'PFTO',
#   'PAOO',
#   '9AK',
#   'TLT',
#   'A61',
#   '4KA',
#   'A63',
#   '9A8',
#   'PAUM',
#   'PAUN',
#   'PADU',
#   'PAVD',
#   'K55',
#   'PAVE',
#   'PAWI',
#   'PAIW',
#   'PAWS',
#   'PAWM',
#   'PAWR',
#   'PAUO',
#   'WSM',
#   'PAWG',
#   'PAYA',
#   '3AK',
#   'A67',
#   'A69',
#   'A68',
#   'AK76',
#   'A57',
#   'A77',
#   'L20'],
#  'AZ': ['P01',
#   'E51',
#   'E95',
#   'P04',
#   'KBXK',
#   'KIFP',
#   'A20',
#   'A09',
#   'KCGZ',
#   'KCHD',
#   'P19',
#   'E91',
#   'Z95',
#   'KCFT',
#   'KAZC',
#   'P08',
#   'P52',
#   'P03',
#   'KDGL',
#   'KDUG',
#   'E60',
#   'KFLG',
#   'KFHU',
#   'E63',
#   'KGEU',
#   'P13',
#   'KGYR',
#   '40G',
#   'KGCN',
#   'P14',
#   '0V7',
#   'E67',
#   'KIGM',
#   'KHII',
#   'KAVQ',
#   'KMZJ',
#   'L41',
#   'A39',
#   'L25',
#   'KFFZ',
#   'KOLS',
#   'KPGA',
#   'P20',
#   'KPAN',
#   '1G4',
#   'L37',
#   'P48',
#   'KPHX',
#   'KIWA',
#   'KDVT',
#   'E37',
#   'P10',
#   'KPRC',
#   'KSAD',
#   '44A',
#   'E77',
#   'KSDL',
#   'KSEZ',
#   'P23',
#   'E78',
#   'KSOW',
#   'KJTC',
#   'KSJN',
#   'E81',
#   'KTYL',
#   'U30',
#   'P29',
#   'T03',
#   'KTUS',
#   'KRYN',
#   'E24',
#   '1Z1',
#   'E25',
#   'P33',
#   'KCMR',
#   'KRQE',
#   'KINW',
#   'KNYL'],
#  'AR': ['M73',
#   'KADF',
#   'KCVK',
#   'M60',
#   'M74',
#   'KBVX',
#   'KSUZ',
#   'KVBT',
#   '4M1',
#   '17A',
#   'KBYH',
#   'KHKA',
#   '4M2',
#   'M36',
#   '37T',
#   'KCDH',
#   '4M3',
#   '4M8',
#   'H35',
#   'KCCA',
#   '2A2',
#   'KDRP',
#   'KCXW',
#   '4M9',
#   'KCRT',
#   '32A',
#   'KDEQ',
#   '5M1',
#   '5M5',
#   '4M5',
#   '0M0',
#   'KELD',
#   'F43',
#   'KFYV',
#   'KXNA',
#   'KFLP',
#   '5M4',
#   'KFCY',
#   'KFSM',
#   '12A',
#   '5M8',
#   '0R6',
#   'KHRO',
#   '6M0',
#   'KHBZ',
#   'KHEE',
#   '2A6',
#   'M18',
#   '6M2',
#   'KHOT',
#   'H34',
#   'KJBR',
#   'M32',
#   '3M0',
#   'KLIT',
#   'KAGO',
#   'M78',
#   'KMXA',
#   '6M7',
#   '6M8',
#   '4A5',
#   '7M1',
#   '42A',
#   'KMEZ',
#   'KLLQ',
#   'KMPJ',
#   'KBDQ',
#   '7M3',
#   'KBPK',
#   '7M2',
#   'M77',
#   'M19',
#   'KORK',
#   '7M4',
#   '7M5',
#   'KPGR',
#   '7M6',
#   '7M7',
#   'KPBF',
#   'M70',
#   '4F7',
#   '7M8',
#   'KROG',
#   'KRUE',
#   '7M9',
#   'KSRC',
#   '9M8',
#   '99A',
#   'KSLG',
#   'KASG',
#   '55M',
#   '4F8',
#   'KSGT',
#   'KTXK',
#   'M27',
#   'KARG',
#   '3M9',
#   '8M2',
#   'KAWM'],
#  'CA': ['A26',
#   'L54',
#   'L70',
#   'KAAT',
#   'A24',
#   '2O3',
#   'KAPV',
#   'KACV',
#   'KMER',
#   'KAUN',
#   'KAVX',
#   '0O2',
#   'KBFL',
#   'L45',
#   'KBNG',
#   'O02',
#   'O55',
#   'L35',
#   'KBIH',
#   'KBLH',
#   'D83',
#   'L08',
#   'KBWC',
#   'O57',
#   'KBUR',
#   'L62',
#   'C83',
#   'KCXL',
#   'L71',
#   'KCLR',
#   'KCMA',
#   'O61',
#   'KCRQ',
#   'O59',
#   '49X',
#   'O05',
#   'KCIC',
#   'KCNO',
#   'L77',
#   '2O6',
#   'O60',
#   '3O8',
#   'C80',
#   'O22',
#   'O08',
#   'KCPM',
#   'KCCR',
#   '0O4',
#   'KAJO',
#   'O09',
#   'KCEC',
#   'KDAG',
#   'KEDU',
#   'KDWA',
#   'L06',
#   'L09',
#   'KDLO',
#   'D63',
#   'A32',
#   '1O6',
#   'KEMT',
#   'KBLU',
#   'KEKA',
#   'O33',
#   'O19',
#   'O89',
#   'L18',
#   'L73',
#   'F34',
#   'A28',
#   'A30',
#   'KFOT',
#   'F72',
#   'KFAT',
#   'KFCH',
#   'E79',
#   'KFUL',
#   'O16',
#   '0O9',
#   'E36',
#   'KGOO',
#   'E45',
#   'E55',
#   '3O1',
#   'KHAF',
#   'KHJO',
#   '36S',
#   'KHHR',
#   'F62',
#   'KHWD',
#   'KHES',
#   'KHMT',
#   'H37',
#   'L26',
#   'KCVH',
#   '1C9',
#   'O21',
#   'H47',
#   'KIPL',
#   '2O7',
#   'KIYK',
#   'KJAQ',
#   'L78',
#   'L05',
#   'KKIC',
#   'S51',
#   'KPOC',
#   '1O2',
#   'KWJF',
#   'O24',
#   'KLHM',
#   'KLLR',
#   'KLVK',
#   '1O3',
#   'O20',
#   'L53',
#   'KLPC',
#   'O26',
#   'KLGB',
#   'KWHP',
#   'KLAX',
#   'KLSN',
#   'KMAE',
#   'KMMH',
#   'KOAR',
#   'KMPI',
#   'M45',
#   'KMYV',
#   'M90',
#   'KMCE',
#   'KMOD',
#   'KMHV',
#   'KSIY',
#   '1O5',
#   'KMRY',
#   'F70',
#   'KAPC',
#   'KEED',
#   'KDVO',
#   'O27',
#   'KOAK',
#   'L52',
#   'KOKB',
#   'L90',
#   'KONT',
#   'O37',
#   'KOVE',
#   'KOXR',
#   'KPSP',
#   'KTRM',
#   'KUDD',
#   'KPMD',
#   'KPAO',
#   'KPRB',
#   'L65',
#   'O69',
#   'KPVF',
#   'KPTV',
#   '2O1',
#   'KRNM',
#   'KRIU',
#   'O39',
#   'KRBL',
#   'KRDD',
#   'O85',
#   'KREI',
#   'O32',
#   'L36',
#   'O88',
#   'KRIV',
#   'KRAL',
#   'KRIR',
#   'L00',
#   'T42',
#   'KSAC',
#   'KMCC',
#   'KMHR',
#   'KSMF',
#   'KSNS',
#   'KSAS',
#   'KCPU',
#   'KSBD',
#   'KSQL',
#   'KMYF',
#   'KSDM',
#   'KSAN',
#   'KSEE',
#   'KSFO',
#   'KSJC',
#   'KRHV',
#   'KSBP',
#   'E16',
#   'KSNA',
#   'KSBA',
#   'KSMX',
#   'KSMO',
#   'KSZP',
#   'KSTS',
#   'KIZA',
#   '0Q3',
#   '0Q4',
#   'KMIT',
#   '0Q5',
#   'L61',
#   'O79',
#   '0Q9',
#   'KTVL',
#   'KSCK',
#   '1Q1',
#   'KSVE',
#   '1Q2',
#   'L17',
#   'KTSP',
#   'L94',
#   'KTOA',
#   'KTCY',
#   '1Q4',
#   'O86',
#   'L72',
#   'KTRK',
#   'KTLR',
#   'O81',
#   'O15',
#   'KTNP',
#   'KUKI',
#   'KCCB',
#   '1Q5',
#   'KVCB',
#   'KVNY',
#   'KVCV',
#   'KVIS',
#   'D86',
#   'L19',
#   'KWVI',
#   'O54',
#   'O46',
#   'O28',
#   'KWLW',
#   'O42',
#   'O41',
#   'O52',
#   'L22'],
#  'CO': ['KAKO',
#   'KALS',
#   'KASE',
#   '05V',
#   'KBDU',
#   '7V5',
#   'KAEJ',
#   'KITR',
#   '5V4',
#   '1V6',
#   '1V8',
#   'KCOS',
#   'KFLY',
#   'KCEZ',
#   'KCAG',
#   '99V',
#   'C24',
#   'KRCV',
#   'KAJZ',
#   'D17',
#   'KAPA',
#   'KBJC',
#   'KDEN',
#   'KCFO',
#   '8V6',
#   'KDRO',
#   '00C',
#   '9V7',
#   'KEGE',
#   'CO4',
#   'KEIK',
#   'KFNL',
#   'KFMM',
#   'KGWS',
#   'KGNB',
#   'KGJT',
#   'KGXY',
#   '11V',
#   'KGUC',
#   '17V',
#   'KHDN',
#   'K08',
#   'KHEQ',
#   '18V',
#   '7V8',
#   '20V',
#   'KLHX',
#   '07V',
#   'KLAA',
#   '7V9',
#   'KLXV',
#   'KLIC',
#   'KLMO',
#   'KEEO',
#   'KMVI',
#   'KMTJ',
#   'KAIB',
#   'KPSO',
#   '7V2',
#   'KPUB',
#   '4V0',
#   'KRIL',
#   '04V',
#   'KANK',
#   '8V7',
#   'KSBS',
#   'KSTK',
#   'KTEX',
#   'KTAD',
#   '33V',
#   '4V1',
#   'C08',
#   '2V5',
#   '2V6'],
#  'CT': ['KBDR',
#   'KSNC',
#   'KDXR',
#   'KLZD',
#   '42B',
#   '7B9',
#   'KGON',
#   'KHFD',
#   '9B8',
#   'KMMK',
#   'KHVN',
#   '11N',
#   'KOXC',
#   '4B8',
#   'C44',
#   '4B9',
#   '7B6',
#   'N41',
#   'KIJD',
#   'KBDL'],
#  'DC': ['KHEF', 'KIAD', 'KDCA'],
#  'DE': ['KDOV',
#   '0N4',
#   '33N',
#   'D74',
#   '0N6',
#   'KGED',
#   'N06',
#   'KEVY',
#   '38N',
#   'KILG',
#   '15N'],
#  'FL': ['KAAF',
#   'F47',
#   'X04',
#   'X06',
#   '0J8',
#   'KAVO',
#   'KBOW',
#   'X10',
#   'F95',
#   'KBCT',
#   '1J0',
#   'KBKV',
#   'X05',
#   'X13',
#   'KCDK',
#   'KCLW',
#   '2IS',
#   'KCEW',
#   'KCTY',
#   'KCGC',
#   'KDAB',
#   '54J',
#   'KDED',
#   '1J6',
#   'KDTS',
#   'X35',
#   'X36',
#   'X55',
#   'X01',
#   'KFHB',
#   'KFXE',
#   'KFLL',
#   'KFMY',
#   'KRSW',
#   'KFPR',
#   'KGNV',
#   '6J8',
#   '01J',
#   'KHWO',
#   'X51',
#   'KIMM',
#   'X58',
#   'KINF',
#   'KJAX',
#   'KCRG',
#   'KVQQ',
#   'KHEG',
#   'KEYW',
#   '42J',
#   'X14',
#   'KLCQ',
#   'X07',
#   'X25',
#   'KLAL',
#   'X49',
#   'KLEE',
#   '24J',
#   'KMTH',
#   'KMKY',
#   'KMAI',
#   'KMLB',
#   'KCOI',
#   'KOPF',
#   'KMIA',
#   'KTMB',
#   'KTNT',
#   '2R4',
#   'KAPF',
#   '1J9',
#   'KEVB',
#   'X50',
#   'KOCF',
#   'KOBE',
#   'KORL',
#   'KISM',
#   'KSFB',
#   'KMCO',
#   'KOMN',
#   'KPHK',
#   '28J',
#   'KFIN',
#   '48X',
#   '2J0',
#   'KECP',
#   'KPNS',
#   '82J',
#   'KFPY',
#   '2J8',
#   'KPCM',
#   'KPMP',
#   'A51',
#   'KPGD',
#   'F13',
#   '2J9',
#   '2RR',
#   'KSRQ',
#   'X26',
#   'KSEF',
#   'KSGJ',
#   'KSPG',
#   'KPIE',
#   'KSUA',
#   'KTLH',
#   'KTPA',
#   'KVDF',
#   'KTPF',
#   'X39',
#   'KTIX',
#   'X21',
#   'X23',
#   'X59',
#   'KVPS',
#   'KVNC',
#   'KVRB',
#   'X52',
#   'KCHN',
#   'KPBI',
#   'F45',
#   'KLNA',
#   'X60',
#   'KGIF',
#   'X61',
#   'KZPH'],
#  'GA': ['15J',
#   'KABY',
#   'KAMG',
#   'KACJ',
#   '75J',
#   'KAHN',
#   'KATL',
#   'KPDK',
#   'KRYY',
#   'KFTY',
#   'KFFC',
#   'KCCO',
#   'KCVC',
#   'KPUJ',
#   'KAGS',
#   'KDNL',
#   'KBGE',
#   'KBHC',
#   'KDZJ',
#   'KBIJ',
#   'KBQK',
#   '82A',
#   '6A1',
#   '70J',
#   'KCZL',
#   'KCXU',
#   '18A',
#   'KCNI',
#   'KCTJ',
#   'KVPC',
#   '4A4',
#   'KCWV',
#   '48A',
#   'KCSG',
#   'KCKF',
#   'KAJR',
#   '25J',
#   '9A0',
#   'KDNN',
#   '16J',
#   '17J',
#   'KDQH',
#   'KDBN',
#   'KEZM',
#   'KEBA',
#   '49A',
#   'KFZG',
#   '3J6',
#   'KLHW',
#   'KGVL',
#   '3J7',
#   '6A2',
#   'KHMP',
#   '51A',
#   'KAZE',
#   'KHOE',
#   'KJZP',
#   'KJCA',
#   '09J',
#   'KJES',
#   '9A5',
#   'KLGC',
#   'KLZU',
#   '2J3',
#   'KMCN',
#   'KMAC',
#   '52A',
#   'KMQW',
#   'KMHP',
#   'KMLJ',
#   '2J5',
#   'D73',
#   '53A',
#   'KMGR',
#   'KMUL',
#   '4J1',
#   '4J2',
#   'KPXE',
#   'KPIM',
#   '4J5',
#   'KRVJ',
#   'KRMG',
#   'KOKZ',
#   'KSAV',
#   '4J8',
#   'KSSI',
#   'KTBR',
#   'KSBO',
#   'KJYL',
#   'KSYV',
#   'KOPN',
#   'KTVI',
#   'KHQU',
#   'KTMA',
#   'KTOC',
#   'KVLD',
#   'KVDI',
#   '5A9',
#   '5A2',
#   'KIIY',
#   'KAYS',
#   'KBXG',
#   'GA2',
#   'KWDR',
#   '65J'],
#  'HI': ['PHHN',
#   'PHPA',
#   'PHUP',
#   'PHTO',
#   'PHNL',
#   'PHOG',
#   'PHKO',
#   'PHLU',
#   'PHMU',
#   'PHJR',
#   'PHMK',
#   'PHNY',
#   'PHLI',
#   'PHDH'],
#  'ID': ['U36',
#   'U01',
#   'KAOC',
#   '55H',
#   'U45',
#   '52U',
#   'U37',
#   'U46',
#   'U48',
#   'U51',
#   'U54',
#   'U60',
#   'I08',
#   'U02',
#   'KBOI',
#   '65S',
#   'U03',
#   'KBYI',
#   'KEUL',
#   'U65',
#   '0U7',
#   'U70',
#   'C64',
#   'KLLJ',
#   'U72',
#   'C53',
#   'D47',
#   'ID8',
#   'U79',
#   'KCOE',
#   'S77',
#   'U81',
#   '66S',
#   'S84',
#   'U82',
#   'S89',
#   'A05',
#   'C48',
#   'U84',
#   'U58',
#   'KDIJ',
#   'U41',
#   'S90',
#   'S78',
#   'U86',
#   'S92',
#   'U88',
#   'U89',
#   'KGNG',
#   'KGIC',
#   'U91',
#   'KSUN',
#   'U93',
#   'U94',
#   'S66',
#   'U97',
#   'U98',
#   'KIDA',
#   'S81',
#   'U53',
#   'KJER',
#   'S73',
#   'S83',
#   'U61',
#   'U99',
#   'S82',
#   '0U0',
#   'U00',
#   'KLWS',
#   '0U1',
#   '1DA',
#   'U62',
#   '0U2',
#   '0U3',
#   'KMLD',
#   '0U8',
#   'KMYL',
#   '24K',
#   '0U9',
#   '1U0',
#   'U92',
#   '1U1',
#   'U76',
#   '1U2',
#   '1U3',
#   'KMAN',
#   '1U4',
#   '0S5',
#   '67S',
#   '1U6',
#   'S68',
#   '75C',
#   '1U7',
#   '50S',
#   'S75',
#   '1U9',
#   'KPIH',
#   '1S1',
#   '2U0',
#   'U10',
#   '1S6',
#   'KRXE',
#   'U56',
#   '2U4',
#   'KSMN',
#   'KSZT',
#   '2U5',
#   '1S7',
#   'U87',
#   'U78',
#   '85U',
#   'U12',
#   'S72',
#   '2U7',
#   'U63',
#   '2U8',
#   '0ID',
#   '3U0',
#   'KTWF',
#   '3U1',
#   'S87',
#   '3U2',
#   'I92'],
#  'IL': ['C00',
#   'KALN',
#   'K06',
#   'KBLV',
#   'H96',
#   'KBMI',
#   '1C5',
#   'KCPS',
#   'KCIR',
#   'KCTK',
#   'KMDH',
#   'KCUL',
#   '1H8',
#   'KENL',
#   'KCMI',
#   'KORD',
#   'KMDW',
#   'KIGQ',
#   'KARR',
#   '3CK',
#   'KPWK',
#   'KRFD',
#   'KLOT',
#   '06C',
#   'KUGN',
#   'KDPA',
#   'H49',
#   'C82',
#   'KDNV',
#   'KDKB',
#   'KDEC',
#   'C73',
#   'KDTG',
#   '1H2',
#   'KFWC',
#   'KFOA',
#   'KFEP',
#   'C86',
#   'KGBG',
#   '3G8',
#   'C81',
#   'KGRE',
#   '10C',
#   'KHSB',
#   '0C0',
#   '9I0',
#   'H07',
#   '0C2',
#   'KIJX',
#   'KJOT',
#   'KIKK',
#   '3KK',
#   'KEZI',
#   'C75',
#   'KLWV',
#   'KAAA',
#   '3LF',
#   'KMQB',
#   'KMWA',
#   'KMTO',
#   'M30',
#   'KMLI',
#   'C56',
#   'C66',
#   'C09',
#   'KAJG',
#   'C55',
#   'I63',
#   'KMVN',
#   '0C8',
#   'KOLY',
#   '8N2',
#   '5K1',
#   'KPRG',
#   '1C1',
#   'C15',
#   'KPIA',
#   '3MY',
#   'KVYS',
#   'KPJY',
#   'KPPQ',
#   'KPNT',
#   'C77',
#   'KUIN',
#   'KTIP',
#   'KRSV',
#   'KRPJ',
#   '1C8',
#   '5K4',
#   'KSLO',
#   'KSFY',
#   '2H0',
#   'KSAR',
#   'KSPI',
#   'KSQI',
#   'KTAZ',
#   'K96',
#   'C16',
#   'KVLA',
#   '2T2',
#   '2C6'],
#  'IN': ['I99',
#   'KAID',
#   'KANQ',
#   'KGWB',
#   'KHLB',
#   'KBFR',
#   '1I3',
#   'KBMG',
#   'C40',
#   'I91',
#   '0I2',
#   'KBAK',
#   'KCEV',
#   '1I8',
#   'KCFJ',
#   '1I9',
#   'KEKM',
#   '3C1',
#   '78I',
#   'KEVV',
#   '3EV',
#   '5I2',
#   'KFWA',
#   'KSMD',
#   'KFKR',
#   '3FK',
#   'KFRH',
#   '5I6',
#   'KGYY',
#   'KGSH',
#   'KGPC',
#   'KGFD',
#   'I34',
#   '05C',
#   'I61',
#   '64I',
#   '3HO',
#   'KHNB',
#   'KHHG',
#   'KIND',
#   'KTYQ',
#   'KMQJ',
#   'KEYE',
#   'KUMP',
#   'KHFY',
#   '2R2',
#   '7L8',
#   'KJVY',
#   'C62',
#   '50I',
#   'KOXI',
#   'KOKK',
#   '8I3',
#   'KPPO',
#   'KLAF',
#   'C98',
#   '6I4',
#   'KGGP',
#   'C97',
#   'KIMS',
#   'KMZZ',
#   'C92',
#   'KMGC',
#   'KMCX',
#   'KMIE',
#   '7I2',
#   'C03',
#   'KUWL',
#   'I80',
#   'KOVO',
#   'I20',
#   '7I4',
#   'I42',
#   'KGUS',
#   'I76',
#   'C65',
#   'KPLD',
#   'KRZL',
#   'KRID',
#   'KRCR',
#   'I83',
#   '3R8',
#   'KSER',
#   'KGEZ',
#   '5I4',
#   'KSBN',
#   'KSIV',
#   'KTEL',
#   'KHUF',
#   '3I3',
#   'KVPZ',
#   '8I1',
#   'KIWH',
#   'KASW',
#   'KDCY',
#   '4C2',
#   'I72',
#   'KRWN',
#   'I22'],
#  'IA': ['4C7',
#   '4C8',
#   'KAXA',
#   'K98',
#   'C11',
#   'KAMW',
#   'Y43',
#   'KIKV',
#   'KAIO',
#   'KADU',
#   'Y46',
#   'KTZT',
#   'Y48',
#   '4K6',
#   'KBNW',
#   'KBRL',
#   'KCIN',
#   'KCID',
#   'KTVK',
#   'KCNC',
#   'KCCY',
#   'KCKP',
#   'KICL',
#   'KCAV',
#   'KCWI',
#   'KCRZ',
#   '0E9',
#   'KCBF',
#   'KCJJ',
#   'KCSQ',
#   'KDVN',
#   'KDEH',
#   'KDNS',
#   'KDSM',
#   'KDBQ',
#   'IA8',
#   'KEAG',
#   '27P',
#   'I27',
#   'KEGQ',
#   'KEST',
#   'KFFL',
#   'KFXY',
#   'KFOD',
#   'KFSW',
#   'KGFZ',
#   'KGGI',
#   '6K7',
#   'KGCT',
#   'KHPT',
#   'KHNR',
#   '0K7',
#   'KIDG',
#   'KIIB',
#   '6Z6',
#   'KIOW',
#   'KIFA',
#   'KEFW',
#   'KEOK',
#   '6K9',
#   'KOXV',
#   '0Y6',
#   'KLWD',
#   '2VA',
#   'KLRJ',
#   'C27',
#   'KMEY',
#   'KOQW',
#   'C17',
#   'KMIW',
#   'KMCW',
#   'KSXK',
#   '4D8',
#   '7C3',
#   '7C5',
#   'KMXO',
#   '1Y3',
#   'KMPZ',
#   'KMUT',
#   '1Y5',
#   'KTNU',
#   '5D2',
#   'KOLZ',
#   'D02',
#   'I75',
#   'KOOA',
#   'KOTM',
#   '1Y9',
#   'KPEA',
#   'KPRO',
#   'KPOH',
#   '2Y0',
#   '2Y1',
#   'KRDK',
#   '8Y8',
#   'KRRQ',
#   '2Y4',
#   'KSKI',
#   'KSHL',
#   'KSDA',
#   'KISB',
#   'KSUX',
#   'KSPW',
#   '0F3',
#   'KSLB',
#   '8C2',
#   '8C4',
#   '8C5',
#   '8C6',
#   'KVTI',
#   'KAWG',
#   'KALO',
#   'Y01',
#   'C25',
#   'KEBS',
#   '3Y2',
#   '3Y3',
#   '3Y4'],
#  'KS': ['K78',
#   'KANY',
#   '2K8',
#   'K58',
#   'K59',
#   'KADT',
#   '3AU',
#   'K64',
#   '07S',
#   'KRPB',
#   'K61',
#   '1K1',
#   '5K0',
#   '8K0',
#   'KUKL',
#   '01K',
#   'KCNU',
#   '8K8',
#   'KCYW',
#   'KCFV',
#   'KCBK',
#   '3K8',
#   'KCNK',
#   '9K0',
#   'K63',
#   'K65',
#   'KDDC',
#   'KEQA',
#   '9K6',
#   'KEHA',
#   '1K6',
#   '9K7',
#   'KEMP',
#   '13K',
#   'KFLV',
#   'KFSK',
#   '18K',
#   '1K7',
#   'KGCK',
#   'K34',
#   'K68',
#   'KGLD',
#   'KGBD',
#   '9KS',
#   '8K2',
#   'KHYS',
#   'KHRU',
#   'K87',
#   'KHLC',
#   'M66',
#   'K91',
#   '1F5',
#   'KHQG',
#   'KHUT',
#   'KIDP',
#   '30K',
#   'K88',
#   'K79',
#   'KJHN',
#   '3JC',
#   '9K8',
#   '33K',
#   '4KS',
#   'K94',
#   '36K',
#   'KLQR',
#   'KLWC',
#   '3K7',
#   'KLBL',
#   'K71',
#   '38K',
#   '39K',
#   'KLYO',
#   'KMHK',
#   'KTKO',
#   '43K',
#   'KMYZ',
#   'KMPR',
#   'KMEJ',
#   'K51',
#   '45K',
#   '2K6',
#   'K17',
#   '47K',
#   '2K7',
#   '48K',
#   'KEWK',
#   'KNRN',
#   '49K',
#   'KOEL',
#   'KOIN',
#   'KIXD',
#   'KOJC',
#   '51K',
#   '52K',
#   '53K',
#   'K75',
#   'K67',
#   'KOWI',
#   '55K',
#   'K81',
#   'KPPF',
#   'KPHG',
#   'KPTS',
#   '1KS',
#   '0P1',
#   'KPTT',
#   '1QK',
#   'K50',
#   'KRSL',
#   'K83',
#   'KSLN',
#   '1K9',
#   'KTQK',
#   '61K',
#   '62K',
#   'K82',
#   'KSYF',
#   '3TA',
#   '63K',
#   'KRCP',
#   '19S',
#   '3K3',
#   'KFOE',
#   'KTOP',
#   '5K2',
#   'KULS',
#   '0H1',
#   '69K',
#   'K38',
#   'KEGT',
#   'KICT',
#   'KAAO',
#   'KCEA',
#   'KBEC',
#   '71K',
#   '72K',
#   'KWLD'],
#  'KY': ['KDWU',
#   'KBRY',
#   'KBWG',
#   '1M9',
#   'M34',
#   'KAAS',
#   'I96',
#   'KCVG',
#   '0I8',
#   'KDVK',
#   '8M7',
#   'KEKX',
#   '2I3',
#   'K62',
#   'KFGX',
#   'KFFT',
#   '1M7',
#   '27K',
#   'KGLW',
#   'M21',
#   'I93',
#   'I35',
#   'KJQD',
#   'KCPF',
#   'KEHR',
#   'KHVC',
#   'KJKL',
#   'K24',
#   'M20',
#   'KY8',
#   'KLEX',
#   'KLOZ',
#   'KSDF',
#   'KLOU',
#   '2I0',
#   '5M9',
#   'M25',
#   '1A6',
#   'KEKQ',
#   'KSYM',
#   'KIOB',
#   'KCEY',
#   'KOWB',
#   'KPAH',
#   'KPBX',
#   '18I',
#   'KSJS',
#   '2M0',
#   '8M9',
#   'KRGA',
#   '4M7',
#   'KSME',
#   '6I2',
#   'I50',
#   'KTWT',
#   'KTZV',
#   '9I3',
#   'KBYL'],
#  'LA': ['KIYA',
#   'KAEX',
#   'KESF',
#   '5F0',
#   'KBQP',
#   'KBTR',
#   'KBXA',
#   '2R6',
#   'F86',
#   '0R7',
#   'L31',
#   '3R2',
#   '5R8',
#   'KDRI',
#   '0M9',
#   '4R7',
#   'F87',
#   '2R7',
#   'KGAO',
#   'KREG',
#   'KHDC',
#   '5F4',
#   'KHUM',
#   'LA3',
#   '2R1',
#   '1R1',
#   '3R7',
#   'F88',
#   'L32',
#   '5F5',
#   'KLFT',
#   'KCWF',
#   'KLCH',
#   '0M8',
#   'L39',
#   '3F3',
#   '3R4',
#   'KMKV',
#   'KMNE',
#   'KMLU',
#   'KIER',
#   'KARA',
#   'KNEW',
#   'KMSY',
#   'KHZR',
#   '9M6',
#   'KACP',
#   'L47',
#   'KOPL',
#   'KPTN',
#   '2L0',
#   'L66',
#   'M79',
#   'KAPS',
#   'KRSN',
#   'KSHV',
#   'KDTN',
#   'KASD',
#   'KSPH',
#   'L33',
#   'KUXL',
#   'KTVR',
#   'M80',
#   'L83',
#   '0R4',
#   '3F4',
#   '6R1',
#   '0R5',
#   'F89',
#   '1R4'],
#  'ME': ['KLEW',
#   'KAUG',
#   'KBGR',
#   'KBHB',
#   'KBST',
#   '0B1',
#   'B19',
#   '08B',
#   '0B2',
#   'KBXM',
#   'KCAR',
#   'B21',
#   'ME2',
#   '43B',
#   '1B0',
#   '3S2',
#   '44B',
#   'KEPM',
#   '3B4',
#   'KFVE',
#   'KIZG',
#   '3B1',
#   'KHUL',
#   '57B',
#   '59B',
#   'PG1',
#   '63B',
#   'KLRG',
#   'B10',
#   '65B',
#   'KMVM',
#   '66B',
#   'KMLT',
#   'KOWK',
#   'KOLD',
#   '81B',
#   '2B7',
#   'KPWM',
#   'KPQI',
#   'KPNN',
#   '8B0',
#   'KRKD',
#   '98M',
#   'KSFM',
#   '93B',
#   'ME5',
#   '3B5',
#   'ME6',
#   'KWVL',
#   'KIWI'],
#  'MD': ['KANP',
#   'KMTN',
#   'KBWI',
#   'W48',
#   'W00',
#   'KCGE',
#   '0W3',
#   'W32',
#   'KCGS',
#   'W41',
#   'KCBE',
#   '1W3',
#   'KESN',
#   '58M',
#   'W42',
#   'KFME',
#   'KFDK',
#   'KVKX',
#   'KGAI',
#   'KHGR',
#   '2W5',
#   'W50',
#   '2W6',
#   'MD1',
#   '2G4',
#   'KOXB',
#   'KRJD',
#   'KSBY',
#   '1N5',
#   'W29',
#   '3W3',
#   'KDMW',
#   '2W2'],
#  'MA': ['8B5',
#   'KBED',
#   '1M8',
#   'KBVY',
#   'KBOS',
#   'KCQX',
#   '1B2',
#   '5B6',
#   'KFIT',
#   'KGDM',
#   'KGBR',
#   '28M',
#   '1B6',
#   'KHYA',
#   'KLWM',
#   '1B9',
#   'KGHG',
#   '2B1',
#   '0B5',
#   'KACK',
#   'KEWB',
#   '2B2',
#   'KAQW',
#   '7B2',
#   'KOWD',
#   'KORE',
#   'KPSF',
#   'KPYM',
#   'KPVC',
#   '3B0',
#   '60M',
#   'KCEF',
#   '3B3',
#   '6B6',
#   'KTAN',
#   'KMVY',
#   'KBAF',
#   'KORH'],
#  'MI': ['KADG',
#   '35D',
#   'KAMN',
#   'KAPN',
#   'KARB',
#   'Y93',
#   '39G',
#   'KBAX',
#   'E53',
#   '7D3',
#   '4M4',
#   '41G',
#   'KBTL',
#   '3CM',
#   'KSJX',
#   '6Y8',
#   'KACB',
#   '43G',
#   'KBEH',
#   'C20',
#   'KRQB',
#   '44G',
#   '6Y1',
#   'N98',
#   'KBFA',
#   '45G',
#   '6G8',
#   'KCAD',
#   'W87',
#   'KCFS',
#   'KCVX',
#   'KFPK',
#   '49G',
#   'KSLH',
#   '2M7',
#   '50G',
#   '48D',
#   'MI1',
#   '7N4',
#   '51G',
#   'KOEB',
#   '56M',
#   '55G',
#   '50D',
#   'KDTW',
#   'KYIP',
#   'KDET',
#   'KONZ',
#   '2E8',
#   'C91',
#   'KDRM',
#   '29M',
#   'Y94',
#   '6D9',
#   '59M',
#   '60G',
#   '68R',
#   '2E2',
#   'Y87',
#   'KESC',
#   '9C8',
#   'KFNT',
#   '3DA',
#   '65G',
#   '66G',
#   'KFKS',
#   'KFFX',
#   '39Z',
#   'KGLR',
#   '4Y4',
#   'KGDW',
#   '5M6',
#   '3GM',
#   '4D0',
#   'Y98',
#   'KGRR',
#   'KGOV',
#   '6D6',
#   '69G',
#   'H80',
#   'KCMX',
#   'KMGN',
#   '4Y9',
#   '80D',
#   '5Y0',
#   'Z92',
#   'C04',
#   '9D9',
#   '5Y1',
#   'Y95',
#   'KJYM',
#   'KBIV',
#   'KHLM',
#   'KHTL',
#   '5Y2',
#   'KOZW',
#   '4Y1',
#   'Y65',
#   'Y88',
#   'Y70',
#   'KIMT',
#   'Y73',
#   'KIWD',
#   'M61',
#   'KJXN',
#   '08C',
#   'KAZO',
#   '4N0',
#   'Y89',
#   '24M',
#   '15W',
#   'Y91',
#   'D15',
#   '13C',
#   'KDUH',
#   'KLAN',
#   'D95',
#   '8M8',
#   '7MI',
#   '3L7',
#   '9G2',
#   '24C',
#   'KLDM',
#   '5Y4',
#   'KMCD',
#   'D90',
#   '75G',
#   'KMBL',
#   'KISQ',
#   '76G',
#   '77G',
#   'KSAW',
#   'KRMY',
#   'KTEW',
#   '27C',
#   '0C5',
#   'KMNM',
#   'KIKW',
#   '51M',
#   'KTTF',
#   '6Y0',
#   'KMOP',
#   '5Y7',
#   'KMKG',
#   '3NP',
#   '6H4',
#   '26W',
#   'Y47',
#   'KERY',
#   '6Y5',
#   '3TR',
#   '6Y3',
#   '5D5',
#   '33C',
#   '5N7',
#   'KOGM',
#   'KOSC',
#   'KRNP',
#   '2H4',
#   '2C5',
#   'KPLN',
#   '88G',
#   '52I',
#   '61D',
#   '1D2',
#   'KPTK',
#   '29C',
#   'KPHN',
#   'M86',
#   '57D',
#   'KRCT',
#   '6Y4',
#   '35C',
#   'KPZQ',
#   'D98',
#   '3RC',
#   'KMBS',
#   'KHYX',
#   'Y83',
#   '96G',
#   'KANJ',
#   'KCIU',
#   'P97',
#   '98G',
#   '6Y9',
#   'KLWA',
#   '8D4',
#   '5Y5',
#   '6Y6',
#   '83D',
#   '3S5',
#   '97G',
#   '39T',
#   'M99',
#   '38C',
#   'KIRS',
#   'C43',
#   '3TE',
#   '22T',
#   '34G',
#   '7Y2',
#   'KHAI',
#   'Y30',
#   'KTVC',
#   '4M0',
#   'KVLL',
#   '40C',
#   '41C',
#   'D11',
#   'Y31',
#   '3F5',
#   '42C',
#   '89Y',
#   '53W',
#   '4Y8',
#   'D20',
#   '48G',
#   'Z98'],
#  'MN': ['D00',
#   'KAIT',
#   'KAEL',
#   'KAXN',
#   'KAQP',
#   'KAUM',
#   '7Y3',
#   '7Y4',
#   'KBDE',
#   'KBJI',
#   'KBBB',
#   '7Y9',
#   'KFOZ',
#   'KSBU',
#   '9Y0',
#   'KBRD',
#   '6D1',
#   'KCFE',
#   'KCHU',
#   'KCBG',
#   'KCNB',
#   '8Y5',
#   '8Y6',
#   'KCOQ',
#   'KCQM',
#   'KCKN',
#   'KDTL',
#   'KTOB',
#   'KDLH',
#   'KDYT',
#   '9Y2',
#   'Y63',
#   'KELO',
#   'KEVM',
#   'KFRM',
#   'KFBL',
#   'KFFM',
#   'D14',
#   '25D',
#   'KFSE',
#   'KGYL',
#   'KGHW',
#   'KCKC',
#   'KGPZ',
#   'KGDB',
#   '3G2',
#   'KHCO',
#   '04Y',
#   '1D6',
#   '05Y',
#   '06Y',
#   'KHIB',
#   '07Y',
#   '04W',
#   'KHCD',
#   'KINL',
#   'KMJQ',
#   '23D',
#   '12Y',
#   'KLJF',
#   'KLXL',
#   '13Y',
#   '14Y',
#   'KXVG',
#   'KLYV',
#   'KDXX',
#   '3N8',
#   'KMKT',
#   'KMGG',
#   'KMML',
#   'KHZX',
#   '18Y',
#   'KFCM',
#   'KANE',
#   'KMSP',
#   'KMIC',
#   'KLVN',
#   'KMVE',
#   'KJKJ',
#   'KMZH',
#   'KJMR',
#   'KMOX',
#   '5C3',
#   'KULM',
#   '43Y',
#   'KOVL',
#   'KORB',
#   'KVVV',
#   'KOWA',
#   'KPKD',
#   'KPEX',
#   '47Y',
#   '16D',
#   'KPWC',
#   '48Y',
#   'KPQN',
#   'KFKA',
#   'KPNM',
#   'D81',
#   'KRGK',
#   'KRWF',
#   '52Y',
#   'KRST',
#   'KROX',
#   'KROS',
#   '55Y',
#   'D39',
#   'KDVP',
#   'Y58',
#   'KSGS',
#   'D42',
#   'KSTC',
#   'KJYG',
#   'KSTP',
#   '21D',
#   'KSYN',
#   'KSAZ',
#   'D32',
#   'D41',
#   'KTVF',
#   '12D',
#   'KTKC',
#   'KTWM',
#   '63Y',
#   'KADC',
#   'Y49',
#   'D37',
#   'KRRT',
#   'KACQ',
#   'KVWU',
#   '68Y',
#   'KETH',
#   'KBDH',
#   'KMWM',
#   'KONA',
#   '10D',
#   'KOTG'],
#  'MS': ['M40',
#   '9M4',
#   'KPMU',
#   '00M',
#   'KHSA',
#   '01M',
#   '1M2',
#   '8M1',
#   '1R7',
#   '08M',
#   '09M',
#   'KCKM',
#   'KRNV',
#   '0R0',
#   'KUBS',
#   'KGTR',
#   'KCRX',
#   'C71',
#   'M11',
#   '66Y',
#   'M37',
#   '06M',
#   '2M4',
#   'KGLH',
#   'KGWO',
#   'KGNF',
#   'KGPT',
#   'KHBG',
#   'KPIB',
#   'H75',
#   'MS9',
#   '14M',
#   'M41',
#   'M44',
#   'KIDL',
#   '15M',
#   'KJAN',
#   'KHKS',
#   'KOSX',
#   'KLUL',
#   '19M',
#   'KLMS',
#   '4R1',
#   '20M',
#   'KMBO',
#   '17M',
#   'KMMS',
#   'KMCB',
#   'KMEI',
#   'KHEZ',
#   'M72',
#   'M23',
#   '5R2',
#   '5A4',
#   'KOLV',
#   'KUOX',
#   'KPQL',
#   'KMPE',
#   'KMJD',
#   '04M',
#   '22M',
#   'M13',
#   'M43',
#   '23M',
#   'KJVW',
#   'M59',
#   '25M',
#   'KSTF',
#   'M51',
#   'KUTA',
#   '30M',
#   'KTUP',
#   'T36',
#   'KVKS',
#   '33M',
#   '2R0',
#   'M83',
#   'M24',
#   '5A6',
#   '87I'],
#  'MO': ['K19',
#   '2H2',
#   'KAOV',
#   '2M1',
#   '75K',
#   'H57',
#   'M17',
#   '1BT',
#   'KVER',
#   'H19',
#   'KBBG',
#   'KPLK',
#   'KFWB',
#   'MO8',
#   'H17',
#   'KBUM',
#   'KTVB',
#   'KOZS',
#   'KEZZ',
#   '34M',
#   'KCGI',
#   'K26',
#   'M05',
#   '94K',
#   'KCHQ',
#   'KCHT',
#   'KGLY',
#   'KCOU',
#   'KUBX',
#   '0C1',
#   'KDXE',
#   'X33',
#   '87K',
#   'H79',
#   '3EX',
#   'KFAM',
#   'KFES',
#   'KTBN',
#   'H88',
#   'KFTT',
#   'H27',
#   'M85',
#   '3GV',
#   'KHAE',
#   'KLRY',
#   'M28',
#   '63M',
#   'KHIG',
#   '37M',
#   'M48',
#   'KJEF',
#   'KJLN',
#   '0H7',
#   'KAIZ',
#   'KMKC',
#   'KMCI',
#   'KTKX',
#   'KIRK',
#   'KLLU',
#   'KLBO',
#   'KLXT',
#   '4K3',
#   '0N0',
#   '0R2',
#   '1H3',
#   'K89',
#   'KMAW',
#   '03B',
#   'KMHL',
#   'KEVU',
#   '78Y',
#   '03D',
#   'KMYJ',
#   'MO9',
#   'KMBY',
#   'KHFJ',
#   'K52',
#   '6M6',
#   'KGPH',
#   'M71',
#   '2MO',
#   '1MO',
#   'KMNF',
#   'KEOS',
#   'KNVD',
#   'KEIW',
#   'K15',
#   'KPCD',
#   'KPYN',
#   'KPOF',
#   '8WC',
#   'MO1',
#   'K07',
#   'KVIH',
#   'K33',
#   'KDMO',
#   'H58',
#   '6K2',
#   'KSIK',
#   'KSGF',
#   '3DW',
#   'MO2',
#   'KSET',
#   'KSTJ',
#   'KSUS',
#   'KSTL',
#   '1H0',
#   'M12',
#   'MO3',
#   'KUUV',
#   'K57',
#   '42M',
#   'KTRX',
#   'K43',
#   'MO5',
#   '3VS',
#   'KRCM',
#   'KRAW',
#   'KFYG',
#   'KUNO',
#   '1H5'],
#  'MT': ['3U3',
#   '3U4',
#   '3U7',
#   '3U5',
#   '49S',
#   'KBHK',
#   '3U8',
#   '6S0',
#   '53U',
#   'KBIL',
#   '3U9',
#   'KBZN',
#   '6S1',
#   '00F',
#   '8S0',
#   'KBTM',
#   'KLTY',
#   'S71',
#   'KCII',
#   '4U6',
#   'RC0',
#   'M46',
#   '6S3',
#   'S04',
#   '4U7',
#   'S01',
#   'S85',
#   'KCTB',
#   '38S',
#   '4U9',
#   '5U0',
#   'KDLN',
#   'M26',
#   '5U1',
#   '97M',
#   'KEKS',
#   '88M',
#   '5U5',
#   '5U6',
#   '1S3',
#   '79S',
#   '37S',
#   '5U7',
#   '29S',
#   '5U8',
#   'KGGW',
#   'KGDV',
#   'KGTF',
#   '6S5',
#   '00U',
#   '48S',
#   'U09',
#   'KHWQ',
#   'KHVR',
#   'KHLN',
#   '6U5',
#   '6U6',
#   'S09',
#   '6U7',
#   'KJDN',
#   'KGPI',
#   'S27',
#   '6S8',
#   '80S',
#   'KLWT',
#   'S59',
#   'S69',
#   'KLVM',
#   'M75',
#   '0S1',
#   'KMLS',
#   'KMSO',
#   'S00',
#   'U05',
#   'S34',
#   'KPWD',
#   '8S1',
#   'PO1',
#   'H28',
#   'KRED',
#   '7U8',
#   '7S0',
#   'KRPX',
#   'M42',
#   '8U0',
#   '8U1',
#   '8U2',
#   '9S2',
#   '8U3',
#   '23S',
#   'KSBX',
#   'KSDY',
#   '8U4',
#   '52S',
#   'S64',
#   '32S',
#   '9S4',
#   '7S8',
#   '8U6',
#   'KTHM',
#   '9S5',
#   'B70',
#   '8U8',
#   '8U9',
#   '57S',
#   '9U0',
#   '7S1',
#   '7S7',
#   'KWYS',
#   '7S6',
#   '58S',
#   '9U1',
#   '9S7',
#   'BB0',
#   'BW8',
#   'CW0',
#   'WH0',
#   'LC0',
#   'L51',
#   'MT3',
#   '7S2',
#   '7S4',
#   '02T',
#   'KOLF'],
#  'NE': ['KANW',
#   'KBVN',
#   'KAIA',
#   '4D9',
#   '37V',
#   '8V2',
#   'K01',
#   'KAUH',
#   'KRBE',
#   'KBIE',
#   '42V',
#   'KBTA',
#   '84Y',
#   'KBBW',
#   'KBUB',
#   'KCSB',
#   '07K',
#   'KCDR',
#   'KCNP',
#   'KOLU',
#   'KCZD',
#   '6K3',
#   'KCEK',
#   '47V',
#   '93Y',
#   'KFBY',
#   'KFMZ',
#   'KFNB',
#   'KFET',
#   '97Y',
#   'KGRN',
#   'KGTE',
#   'KGRI',
#   'KGGF',
#   '0B4',
#   '08K',
#   'KHSI',
#   '4V6',
#   'KHJH',
#   'KHDE',
#   '1V2',
#   'KIML',
#   'KEAR',
#   'KIBM',
#   'KLXN',
#   'KLNK',
#   '0F4',
#   'KMCK',
#   '0V3',
#   'KAFK',
#   '4V9',
#   'KOFK',
#   'KLBF',
#   'KONL',
#   'KOGA',
#   'KOMA',
#   'KMLE',
#   '3NO',
#   'KODX',
#   'KOKS',
#   '50K',
#   '0C4',
#   'KPMV',
#   '7V7',
#   '9V5',
#   '09K',
#   'KBFF',
#   'KSCB',
#   'KSWT',
#   'KSNY',
#   '7K8',
#   '12K',
#   '0G3',
#   'KTQE',
#   'KTIF',
#   '0J9',
#   'KVTN',
#   'KAHQ',
#   '64V',
#   'KLCG',
#   'KJYR'],
#  'NV': ['L92',
#   'KTMT',
#   'KBAM',
#   'KBTY',
#   'KBVU',
#   '1L4',
#   'KCXP',
#   'U74',
#   '9U7',
#   'A34',
#   'E85',
#   '01U',
#   '2Q9',
#   'KEKO',
#   'KELY',
#   '05U',
#   'KFLX',
#   'N58',
#   'KGAB',
#   '0L4',
#   'KHTH',
#   '06U',
#   '0L7',
#   'N15',
#   'KLAS',
#   'KHND',
#   'KVGT',
#   'KLOL',
#   '67L',
#   '3Q0',
#   'KMEV',
#   '08U',
#   'U08',
#   '0L9',
#   '10U',
#   '74P',
#   '1L1',
#   'KRNO',
#   'KRTS',
#   'N86',
#   '3L2',
#   '1L3',
#   'KSPZ',
#   'N59',
#   'KTPH',
#   'KLWL',
#   'KWMC',
#   'O43'],
#  'NH': ['KBML',
#   '2N2',
#   'KCNH',
#   '4C4',
#   'KCON',
#   'KERR',
#   '1B5',
#   '2G8',
#   '7B3',
#   '5B9',
#   '8B1',
#   'KAFN',
#   'KEEN',
#   'KLCI',
#   'KLEB',
#   'KMHT',
#   'KASH',
#   '2B3',
#   '1P1',
#   'KPSM',
#   'KDAW',
#   '8B2',
#   'KHIE'],
#  'NJ': ['12N',
#   '13N',
#   'KACY',
#   'KBLM',
#   '19N',
#   '1N7',
#   '00N',
#   'KCDW',
#   '17N',
#   'N05',
#   'N81',
#   '2N6',
#   'N12',
#   'N07',
#   'KLDJ',
#   'N14',
#   '47N',
#   'KMIV',
#   'KMMU',
#   'KVAY',
#   'KEWR',
#   '26N',
#   '3N6',
#   '7N7',
#   'N40',
#   'N85',
#   '39N',
#   'N51',
#   'N87',
#   'KSMQ',
#   'KFWN',
#   'KTEB',
#   'KMJX',
#   'KTTN',
#   '28N',
#   '29N',
#   '31E',
#   '4N1',
#   'KWWD',
#   'C01',
#   'KOBI'],
#  'NM': ['KALM',
#   'KABQ',
#   'KAEG',
#   'KAXX',
#   '13Q',
#   'KATS',
#   'N19',
#   'KBRG',
#   'KCNM',
#   'F37',
#   'KCAO',
#   'KCVN',
#   'E89',
#   '0E8',
#   'KDMN',
#   '24N',
#   '1N1',
#   'E14',
#   'E92',
#   'KFMN',
#   'KFSU',
#   'KGUP',
#   'E94',
#   'KGNT',
#   'E05',
#   'KHOB',
#   'E26',
#   'KLRU',
#   'KLVS',
#   'E32',
#   'KLSB',
#   'KLAM',
#   'E98',
#   'E06',
#   'N29',
#   '0E0',
#   'M10',
#   '1V0',
#   'KPRZ',
#   'N24',
#   'KRTN',
#   'T16',
#   'KROW',
#   'KSRR',
#   'KSAF',
#   'KSXU',
#   'KDNA',
#   '5V5',
#   'KSVC',
#   '94E',
#   'KONM',
#   'S42',
#   'KSKX',
#   '18T',
#   'KTCS',
#   'KTCC',
#   'N17',
#   'KXNI'],
#  'NY': ['9G3',
#   'KALB',
#   '9G6',
#   'D23',
#   '1C3',
#   'KGVQ',
#   '23N',
#   'KBGM',
#   '7G0',
#   'KBUF',
#   '9G0',
#   'D51',
#   '1B8',
#   'KIUA',
#   '1H1',
#   'K23',
#   '7N1',
#   'N03',
#   'KDSV',
#   '1E8',
#   '4B1',
#   'KDKK',
#   'KHTO',
#   '49N',
#   '1F2',
#   'N89',
#   'KELM',
#   'KCZG',
#   'KFRG',
#   '0B8',
#   '83K',
#   '1I5',
#   'KFZY',
#   'N25',
#   'K30',
#   '9G5',
#   'D52',
#   'NY1',
#   'KGFL',
#   '92G',
#   'D59',
#   'N56',
#   '4N7',
#   '1H4',
#   '4G2',
#   'KVGC',
#   'KHTF',
#   '1B1',
#   'KITH',
#   'KJHW',
#   'NY0',
#   '1I1',
#   '20N',
#   'KLKP',
#   'KBQR',
#   '5G0',
#   '1A1',
#   '0G0',
#   'KMAL',
#   'KMSS',
#   '21N',
#   'D79',
#   '4N2',
#   '06N',
#   '44N',
#   'KMTP',
#   'KMGJ',
#   'KMSV',
#   'KISP',
#   'KSWF',
#   'KJFK',
#   'KLGA',
#   '85N',
#   'KIAG',
#   'KOIC',
#   'KOGS',
#   'KOLE',
#   '8G3',
#   'N66',
#   'D82',
#   'KPEO',
#   '01G',
#   'K09',
#   'KPBG',
#   'KPTD',
#   'KPOU',
#   '46N',
#   'KROC',
#   'KRME',
#   'K16',
#   'W57',
#   'KSLK',
#   '5B2',
#   'KSCH',
#   '4B7',
#   'B04',
#   '0G7',
#   'K31',
#   'D88',
#   'KHWV',
#   'N23',
#   '6B9',
#   '4B0',
#   'D91',
#   '09N',
#   'N69',
#   'KSYR',
#   '4B6',
#   '5B7',
#   '6B4',
#   'N45',
#   '5R5',
#   'N72',
#   'KART',
#   'B16',
#   'KELZ',
#   'KFOK',
#   'KHPN',
#   'KSDC',
#   'N82'],
#  'NC': ['KASJ',
#   'KVUJ',
#   'KRHP',
#   'KHBI',
#   'KAVL',
#   'KMRH',
#   '3W6',
#   'KBUY',
#   'BQ1',
#   'KCLT',
#   '8A6',
#   'KCTZ',
#   'KJQF',
#   'KONX',
#   'KEDE',
#   'KECG',
#   'KEYF',
#   'KZEF',
#   '7W6',
#   'KHRJ',
#   'N08',
#   'KFAY',
#   '2GC',
#   '1A5',
#   'KAKH',
#   'KGWW',
#   'KGSO',
#   'W88',
#   '3A4',
#   'KPGV',
#   'KHSE',
#   '0A7',
#   'KHKY',
#   'E40',
#   'N21',
#   '4W4',
#   '28A',
#   'KOAJ',
#   'N22',
#   'KGEV',
#   '78A',
#   'N88',
#   'KDPL',
#   'KFFA',
#   'KISO',
#   'W17',
#   'KEXX',
#   '2A5',
#   'N61',
#   'KIPJ',
#   'KLHZ',
#   'KLBT',
#   'N92',
#   'KMQI',
#   '9A9',
#   'KMEB',
#   '8A7',
#   'KEQY',
#   '14A',
#   'KMRN',
#   'KMWK',
#   'W40',
#   'KEWN',
#   'KUKF',
#   'KSUT',
#   'N83',
#   '60J',
#   'W95',
#   'KHNZ',
#   'N26',
#   'KSOP',
#   'KPMZ',
#   '7NC',
#   '5W4',
#   '5W5',
#   'KRDU',
#   'KSIF',
#   '6A5',
#   'KIXA',
#   'KRCZ',
#   'KRWI',
#   '8NC',
#   'KTDF',
#   'KFQD',
#   'KRUQ',
#   'KTTA',
#   'KEHO',
#   'KSCR',
#   'KJNX',
#   '7A8',
#   '43A',
#   'KSVH',
#   '24A',
#   'KETC',
#   'NC2',
#   'N97',
#   'KAFP',
#   'KACZ',
#   'N63',
#   'KOCW',
#   'N52',
#   'KCPC',
#   'KMCZ',
#   'KILM',
#   'W03',
#   'KINT',
#   '05N',
#   '80C',
#   '6W4'],
#  'ND': ['1A2',
#   'KASY',
#   '20U',
#   '95D',
#   'KBIS',
#   'D09',
#   '5B4',
#   'KBWW',
#   '9D7',
#   '46D',
#   '5N8',
#   '2C8',
#   'D49',
#   'S32',
#   'D50',
#   'KDVL',
#   'KDIK',
#   'D29',
#   'S28',
#   '51D',
#   'Y71',
#   '4E7',
#   '5N4',
#   'KFAR',
#   'D54',
#   'D24',
#   'Y27',
#   '9G9',
#   'D05',
#   'D57',
#   'KGAF',
#   'KGFK',
#   'KGWR',
#   '5H4',
#   '6H8',
#   'KHZE',
#   'KHEI',
#   '3H4',
#   'KJMS',
#   '7K5',
#   '9Y1',
#   'K74',
#   'D03',
#   '4F9',
#   '5L0',
#   'D55',
#   '2L1',
#   'D31',
#   '4N4',
#   '7L2',
#   '6L3',
#   '6D3',
#   'Y19',
#   'D56',
#   '7G2',
#   '8M6',
#   '4R6',
#   'KMOT',
#   'D06',
#   'KHBC',
#   '3P3',
#   '5B5',
#   '8J7',
#   '05D',
#   '4V4',
#   '2D5',
#   '64G',
#   'Y37',
#   'Y74',
#   'KPMB',
#   'Y99',
#   '4E8',
#   '37N',
#   '2H9',
#   '06D',
#   'KRUG',
#   '4S5',
#   '08D',
#   'D60',
#   'D61',
#   '91N',
#   'KBAC',
#   'KBWP',
#   '96D',
#   '5C8',
#   'S25',
#   'D64',
#   'KXWA',
#   '6L5'],
#  'OH': ['0D7',
#   'KCAK',
#   'KAKR',
#   '1D4',
#   '2D1',
#   '3G4',
#   'KHZY',
#   'KUNI',
#   '7B4',
#   '6G5',
#   'I69',
#   '2D7',
#   'KEDJ',
#   '5G7',
#   '1G0',
#   '3D8',
#   '0G6',
#   '17G',
#   '8G6',
#   'I10',
#   'KCDI',
#   'KTSO',
#   '5D6',
#   'KCQA',
#   '6CM',
#   'KHTW',
#   'KRZT',
#   'KLUK',
#   'KCYO',
#   'KCLE',
#   'KBKL',
#   'KCGF',
#   '5D9',
#   '4G8',
#   'KCMH',
#   'KOSU',
#   'KLCK',
#   'KTZR',
#   '04I',
#   'I40',
#   'KDAY',
#   'KMGY',
#   'I19',
#   '3I7',
#   'I73',
#   'I44',
#   'KDFI',
#   'KDLZ',
#   '6D7',
#   '02G',
#   '1G1',
#   'KFDY',
#   'KFZI',
#   'S24',
#   '14G',
#   'KGQQ',
#   'KGAS',
#   '7D8',
#   '7D9',
#   'KGEO',
#   'KHAO',
#   'I67',
#   'KHOC',
#   '88D',
#   'I43',
#   '89D',
#   '1G3',
#   'I95',
#   'KLHQ',
#   'I68',
#   'R47',
#   'KAOH',
#   'KUYF',
#   'KLPR',
#   'KMFD',
#   'KMNN',
#   'KMRT',
#   '22I',
#   'I71',
#   '1G5',
#   '3T7',
#   '3W9',
#   '7G8',
#   'KMWO',
#   '10G',
#   '4I9',
#   '4I3',
#   '6G4',
#   'O74',
#   '7W5',
#   'I86',
#   'KPHD',
#   'KVTA',
#   '41N',
#   '3X5',
#   '5A1',
#   'KOWX',
#   'KOXD',
#   '2G1',
#   '6C2',
#   'I17',
#   'KPCW',
#   'KPMH',
#   '3W2',
#   '5E9',
#   'KPOV',
#   '38D',
#   '8G8',
#   '3G6',
#   '12G',
#   'KSCA',
#   'KSGH',
#   '2P7',
#   '2G2',
#   '16G',
#   'KTOL',
#   'KTDZ',
#   '1G8',
#   'I54',
#   '1WF',
#   '56D',
#   'I74',
#   '38I',
#   'KVNW',
#   'KVES',
#   '3G3',
#   '15G',
#   'I64',
#   'KAXV',
#   '62D',
#   'I23',
#   'KUSE',
#   'KEOP',
#   '40I',
#   '80G',
#   'KAMT',
#   '8G1',
#   'KLNN',
#   'KILN',
#   'I66',
#   '2B6',
#   '4G5',
#   'KBJJ',
#   '4G4',
#   '04G',
#   'KYNG',
#   'KZZV',
#   '42I'],
#  'OK': ['KADH',
#   '3O9',
#   'KAXS',
#   'KAVK',
#   'F68',
#   '80F',
#   'KADM',
#   '1F0',
#   'KAQR',
#   'KBVO',
#   'K44',
#   'KBKN',
#   '17K',
#   '3F7',
#   '90F',
#   'KBFK',
#   '37K',
#   'KCSM',
#   '91F',
#   '86F',
#   'KCQB',
#   '92F',
#   '4O5',
#   '93F',
#   'KCHK',
#   'KGCM',
#   'K11',
#   '95F',
#   'KCLK',
#   '08F',
#   '44M',
#   'F36',
#   'KCUH',
#   '97F',
#   'KDUC',
#   'KDUA',
#   'KRQO',
#   '99F',
#   'KELK',
#   'KWDG',
#   'O13',
#   'F08',
#   '0F7',
#   '1OK',
#   '6K4',
#   'KFDR',
#   'K77',
#   'KGAG',
#   '1K4',
#   '1O1',
#   'KGMJ',
#   'KGOK',
#   'KGUY',
#   '2K9',
#   'F32',
#   'F10',
#   '2O8',
#   'KHBR',
#   'F99',
#   'O35',
#   'H92',
#   'O45',
#   'KHHW',
#   '4O4',
#   'O18',
#   '0K6',
#   '1K8',
#   'F92',
#   'F31',
#   'KLAW',
#   'O44',
#   '1K2',
#   '1F4',
#   '2K4',
#   'KMLC',
#   'O53',
#   '4O7',
#   'KMIO',
#   'KMDF',
#   'KMKO',
#   'O14',
#   'KOUN',
#   'H66',
#   'O65',
#   'F81',
#   'KOKC',
#   'KPWA',
#   'KHSD',
#   'KRCE',
#   'KOKM',
#   'F09',
#   'O38',
#   'KPVJ',
#   'H76',
#   'H97',
#   'F22',
#   'KPNC',
#   '2K1',
#   'KRKR',
#   'O47',
#   'H71',
#   '3O3',
#   'KJSV',
#   'KOWP',
#   '3O4',
#   '1S4',
#   'KSRE',
#   'KSNL',
#   '2F6',
#   '4O1',
#   'KGZL',
#   'KSWO',
#   '1PP',
#   'KSUD',
#   'F30',
#   'KTQH',
#   '6F1',
#   '1O4',
#   '1O8',
#   '0F9',
#   'KTUL',
#   'KRVS',
#   '1H6',
#   '5O1',
#   'H04',
#   'H68',
#   '3O5',
#   'KJWG',
#   '1K5',
#   'KOJA',
#   '4F1',
#   'H05',
#   'KWWR'],
#  'OR': ['S12',
#   'R03',
#   '1S8',
#   'S03',
#   'KAST',
#   'KUAO',
#   'KBKE',
#   'S05',
#   '2S2',
#   'KBDN',
#   'M50',
#   'KBOK',
#   'KBNO',
#   'KCZK',
#   '3S4',
#   '2S7',
#   '62S',
#   '3S6',
#   '3S9',
#   '4S4',
#   'KCVO',
#   '61S',
#   '5S2',
#   '77S',
#   '5S5',
#   '8S4',
#   'O62',
#   '5S9',
#   'KEUG',
#   '6S2',
#   '6S4',
#   'S45',
#   '4S1',
#   '3S8',
#   'KHRI',
#   '7S3',
#   '4S2',
#   '7S9',
#   '25U',
#   'OR8',
#   'OR9',
#   '7S5',
#   'KGCD',
#   'KJSY',
#   'KLMT',
#   'KLGD',
#   '9S3',
#   'KLKV',
#   'S30',
#   '9S9',
#   'S33',
#   '4S7',
#   '3S7',
#   '26U',
#   '00S',
#   'KMMV',
#   'KMFR',
#   '12S',
#   '16S',
#   '17S',
#   '2S6',
#   'KONP',
#   'KOTH',
#   '5S0',
#   'KONO',
#   '28U',
#   'KPFC',
#   '22S',
#   'KPDT',
#   '24S',
#   'KHIO',
#   'KPDX',
#   'KTTD',
#   '4S9',
#   '6S6',
#   'S39',
#   '64S',
#   'KRDM',
#   'KREO',
#   'KRBG',
#   '5S1',
#   'KSLE',
#   '03S',
#   'S48',
#   '8S3',
#   'KSPB',
#   '56S',
#   '45S',
#   '6K5',
#   '5S6',
#   'S21',
#   'KDLS',
#   'KTMK',
#   '5S4',
#   'S49',
#   '05S',
#   'R33',
#   '35S'],
#  'PA': ['KABE',
#   'KXLL',
#   'KAOO',
#   '7N8',
#   'KBVI',
#   'KHMZ',
#   'N96',
#   '8N1',
#   'N13',
#   'KBFD',
#   'P17',
#   '9W8',
#   'KBTP',
#   '3G9',
#   '8N4',
#   'N94',
#   'N74',
#   'N16',
#   'N68',
#   'KAXQ',
#   'KFIG',
#   'KMQS',
#   'N10',
#   'KVVS',
#   '8G2',
#   '8N8',
#   '0P8',
#   'KDYL',
#   'KDUJ',
#   'N53',
#   'N43',
#   '9G8',
#   '22D',
#   'KERI',
#   '9N1',
#   '9N3',
#   'W73',
#   'G05',
#   'KFKL',
#   '9N7',
#   '6P7',
#   'P91',
#   'W05',
#   '4G1',
#   '29D',
#   'KCXY',
#   'KMDT',
#   'KHZL',
#   'N30',
#   'KIDI',
#   '31D',
#   '5G8',
#   'P96',
#   'KJST',
#   '07N',
#   'KLNS',
#   'KLBE',
#   '08N',
#   '22N',
#   '14N',
#   'KLHV',
#   'P09',
#   'KGKJ',
#   'P34',
#   'KFWQ',
#   'O03',
#   'N71',
#   'P45',
#   'KMPO',
#   '9D4',
#   'KUCP',
#   '7G4',
#   '58N',
#   'KCKZ',
#   'KPNE',
#   'KPHL',
#   'KLOM',
#   'KPSB',
#   '1N3',
#   'KAGC',
#   'KPIT',
#   '9G1',
#   'P15',
#   'KPTW',
#   'N47',
#   'KZER',
#   'N35',
#   'KUKT',
#   'KRDG',
#   'KRVL',
#   'KSEG',
#   'N79',
#   '69N',
#   'S37',
#   '2G9',
#   'KOYM',
#   'KUNV',
#   '70N',
#   '0P2',
#   '71N',
#   '6G1',
#   'N57',
#   'N27',
#   '74N',
#   '76N',
#   'KAFJ',
#   'KWAY',
#   'N38',
#   '2N5',
#   'KOQN',
#   'KWBW',
#   'KAVP',
#   '6G6',
#   'KIPT',
#   'KTHV',
#   'KPJC'],
#  'RI': ['KBID', 'KUUU', 'KOQU', 'KSFZ', 'KPVD', '08R', 'KWST'],
#  'SC': ['KAIK',
#   'KAQX',
#   'KAND',
#   'KPHH',
#   '99N',
#   'KBNL',
#   'KARW',
#   'KBBP',
#   '52J',
#   'KCDN',
#   'KCHS',
#   'KJZI',
#   'KCQW',
#   'KDCM',
#   'KCEU',
#   '9W9',
#   'KCAE',
#   'KCUB',
#   'KHYW',
#   'KUDG',
#   '6J7',
#   'KDLC',
#   'KFLO',
#   'KGGE',
#   'S17',
#   'S79',
#   'KGMU',
#   'KGYH',
#   'KGRD',
#   'KGSP',
#   '3J0',
#   'KHVS',
#   'KHXD',
#   '5J5',
#   'KCKI',
#   '51J',
#   'KLKR',
#   'T73',
#   '33A',
#   'KLUX',
#   '5J9',
#   'KMNI',
#   'KMAO',
#   'S19',
#   'KMKS',
#   'KLRO',
#   'KMYR',
#   'KEOE',
#   'KCRE',
#   'KOGB',
#   '1DS',
#   'KPYG',
#   '6J0',
#   'KLQK',
#   '3J1',
#   'KUZA',
#   '6J4',
#   'KSPA',
#   '6J2',
#   'KDYB',
#   'KSMS',
#   '58J',
#   '6J6',
#   '35A',
#   'KRBW',
#   'KFDW'],
#  'SD': ['KABR',
#   '3A9',
#   'KEFC',
#   '6V5',
#   'KBTN',
#   'KBKX',
#   '9D2',
#   '7G9',
#   '9V9',
#   '8D7',
#   '5H3',
#   'D65',
#   'KCUT',
#   '6E5',
#   '84D',
#   '6V0',
#   '3W8',
#   '3V0',
#   'D07',
#   '3FU',
#   '4P3',
#   '0D8',
#   '9D1',
#   '2E6',
#   '5T4',
#   '9D0',
#   'KHSR',
#   '9F8',
#   '8D9',
#   'KHON',
#   '3Y7',
#   '5V8',
#   '6A6',
#   '8D8',
#   'Y34',
#   'KLEM',
#   'KMDS',
#   '9V6',
#   '5P2',
#   '1D1',
#   'KMKA',
#   'KMHE',
#   'KMBG',
#   '8F6',
#   '7K7',
#   '98D',
#   '8V3',
#   'KPHP',
#   'KPIR',
#   'KIEN',
#   '1D3',
#   '5P5',
#   'KRAP',
#   '1D8',
#   'KSUO',
#   'KFSD',
#   '8D3',
#   'KSPF',
#   'Y03',
#   '49B',
#   'Y14',
#   'D58',
#   'KVMR',
#   'KAGZ',
#   '6V4',
#   'KATY',
#   '1D7',
#   '4X4',
#   '7Q7',
#   'KICR',
#   'KYKN'],
#  'TN': ['KMMI',
#   'M08',
#   'KTRI',
#   '0M4',
#   'KGHM',
#   'KCHA',
#   '1A0',
#   'KCKV',
#   'KRZR',
#   'M29',
#   'KFGU',
#   'KMRC',
#   '1A3',
#   'M04',
#   'KCSV',
#   '2A0',
#   'M02',
#   'KDYR',
#   '0A9',
#   'KFYM',
#   '1A7',
#   'KXNX',
#   'KGCY',
#   'M31',
#   '0M3',
#   'M53',
#   'KHZD',
#   'KJAU',
#   'KMKL',
#   '2A1',
#   'KAPT',
#   '0A4',
#   'KTYS',
#   'KDKX',
#   '3M7',
#   '2M2',
#   'M54',
#   'KLUG',
#   'KPVE',
#   'M15',
#   '8A3',
#   'KMNV',
#   'M93',
#   'KRNC',
#   'KMEM',
#   'M01',
#   'KNQA',
#   '2M8',
#   'KMOR',
#   '6A4',
#   'KMBT',
#   'KBNA',
#   'KJWN',
#   'KSCX',
#   'KPHT',
#   '1M5',
#   'KGZS',
#   'KRKW',
#   'KRVN',
#   '54M',
#   'KSNH',
#   'KSZY',
#   'KGKT',
#   'KUOS',
#   'KSYI',
#   '0A3',
#   'KMQY',
#   'KFYE',
#   'KSRB',
#   'M91',
#   '3A2',
#   '0M2',
#   'KTGC',
#   'KTHA',
#   'KUCY',
#   '0M5',
#   'KBGF'],
#  'TX': ['KABI',
#   '67T',
#   'T23',
#   'KALI',
#   'E38',
#   '1E2',
#   '6R5',
#   'KAMA',
#   'KTDW',
#   'H81',
#   '1E7',
#   '1E4',
#   'T00',
#   'E11',
#   '81D',
#   '7R9',
#   'KLBX',
#   'T39',
#   'KGKY',
#   'T60',
#   'F44',
#   'KATA',
#   'KAUS',
#   'KEDC',
#   'KHYI',
#   'E30',
#   'KBYY',
#   'KHPY',
#   '54T',
#   '5T0',
#   'KBMT',
#   'KBPT',
#   'KBEA',
#   'TX2',
#   '06R',
#   'E41',
#   'KBPG',
#   '07R',
#   'F00',
#   'KBGD',
#   '0F2',
#   'KBBD',
#   'KBKD',
#   '11R',
#   'KXBP',
#   'KBFE',
#   'KBRO',
#   'KBWD',
#   'KCFD',
#   'KBMQ',
#   '7F3',
#   'KRWV',
#   'T35',
#   'KHHF',
#   '7F5',
#   'KCZT',
#   '4F2',
#   'KCVB',
#   'T80',
#   '9S1',
#   'F17',
#   'KCDS',
#   '3T8',
#   'KGZN',
#   '3F2',
#   'E34',
#   'KLBR',
#   'KCPT',
#   '6R3',
#   '7F7',
#   'KCOM',
#   'KCLL',
#   'T32',
#   'T88',
#   '66R',
#   'KMKN',
#   '2F7',
#   '55T',
#   'KCRP',
#   'KCRS',
#   'KCOT',
#   'E13',
#   'KDKR',
#   '8F3',
#   'T71',
#   '8F5',
#   'KDHT',
#   'KDAL',
#   'KADS',
#   'KTKI',
#   'KRBD',
#   'F69',
#   '1F7',
#   'KDFW',
#   'KLUD',
#   '76T',
#   '58T',
#   '09T',
#   'KDRT',
#   '2E5',
#   'KDTO',
#   'E57',
#   '23R',
#   '24R',
#   'T55',
#   '6R6',
#   '9F0',
#   'KDUX',
#   'KELA',
#   '5T9',
#   'KETN',
#   'KEBG',
#   '26R',
#   'KELP',
#   '27R',
#   'F41',
#   'E35',
#   'KBKS',
#   'TX6',
#   '41F',
#   'T93',
#   'KGRK',
#   'KFST',
#   'KFTW',
#   'KAFW',
#   'KFWS',
#   'T67',
#   '4T2',
#   '9F9',
#   '50F',
#   'T25',
#   'T82',
#   'T19',
#   'X54',
#   'X09',
#   'KGLE',
#   'KGLS',
#   'KGOP',
#   '8T6',
#   'KGTU',
#   'KGYB',
#   'KJXI',
#   '07F',
#   'T37',
#   'T20',
#   '3T0',
#   'F35',
#   'KRPH',
#   '10F',
#   'KGDJ',
#   'KGPM',
#   '2G5',
#   'KGVT',
#   '33R',
#   'E19',
#   '34R',
#   'KMNZ',
#   'KHRL',
#   '15F',
#   'KLHB',
#   'KHBV',
#   'KRFI',
#   'KHRX',
#   '1X1',
#   'KINJ',
#   'KHDO',
#   'KDZB',
#   'KHOU',
#   'KIAH',
#   'KDWH',
#   'KCXO',
#   'KSGR',
#   'KEFD',
#   'KTME',
#   'KIWS',
#   'KLVJ',
#   'KAXH',
#   '9X1',
#   'T51',
#   '2H5',
#   '39R',
#   'KUTS',
#   'KTFP',
#   '2F0',
#   '21F',
#   'KJSO',
#   'KJAS',
#   '22F',
#   '24F',
#   '6F7',
#   'KJCT',
#   '16X',
#   '3T6',
#   'XA0',
#   '2R9',
#   'KERV',
#   'KILE',
#   'KIKG',
#   'T12',
#   'F75',
#   '45R',
#   '29F',
#   'E58',
#   '3T5',
#   'T41',
#   'TX0',
#   'KRYW',
#   'T89',
#   '30F',
#   '3R9',
#   'KLUV',
#   'KLZZ',
#   'KLNC',
#   'KLRD',
#   '49R',
#   'KLLN',
#   'T78',
#   '7T0',
#   'KLIU',
#   '00R',
#   'KAQO',
#   '50R',
#   'KGGG',
#   'T26',
#   'KLBB',
#   'F82',
#   'KLFK',
#   'T91',
#   '51R',
#   '3T2',
#   'KMRF',
#   'T15',
#   'KASL',
#   'T92',
#   'KMFE',
#   'E48',
#   'T31',
#   '2E7',
#   'F21',
#   'T50',
#   'KHQZ',
#   'KLXY',
#   '3E0',
#   'KMAF',
#   'KMDD',
#   '7T7',
#   'T56',
#   'KJWY',
#   '3F9',
#   'KJDD',
#   'KMWL',
#   'E01',
#   'F85',
#   'KOSA',
#   '6X0',
#   'F53',
#   '2T1',
#   '37F',
#   'KOCH',
#   '60R',
#   'KBAZ',
#   '61R',
#   'KODO',
#   'KONY',
#   'KORG',
#   'KOZA',
#   '3F6',
#   'KPSX',
#   'KPSN',
#   'T13',
#   'KPPA',
#   'T45',
#   'KPRX',
#   'T79',
#   'T30',
#   'KPEQ',
#   'KPYX',
#   'T24',
#   'F98',
#   'KPVW',
#   'KPEZ',
#   '74T',
#   'KRAS',
#   'KPIL',
#   'KPKV',
#   'T05',
#   '9R5',
#   '5F1',
#   'KPRS',
#   '3T9',
#   'F01',
#   'T14',
#   'F23',
#   '49F',
#   'KRFG',
#   'T76',
#   '67R',
#   '52F',
#   'KRBO',
#   'KRCK',
#   'KRKP',
#   'KECU',
#   'F46',
#   'T48',
#   'T54',
#   '56F',
#   '2TX',
#   'KSJT',
#   'KSAT',
#   '5C1',
#   'KSKF',
#   'KSSF',
#   '1T8',
#   '1T7',
#   'T94',
#   '8T8',
#   '74R',
#   '78R',
#   '81R',
#   'T58',
#   'T87',
#   '6X8',
#   'F97',
#   'E70',
#   'KGNC',
#   '60F',
#   '2F1',
#   'KSWI',
#   'KGYI',
#   'T69',
#   'F49',
#   '3TX',
#   'T28',
#   '84R',
#   'KSNK',
#   '53T',
#   'KSOA',
#   'E42',
#   '88R',
#   'F56',
#   '63F',
#   'KSEP',
#   'H70',
#   'KSLR',
#   'X43',
#   '2KL',
#   'KSWW',
#   '2F4',
#   'T74',
#   '68F',
#   'KTPL',
#   'KTRL',
#   '72F',
#   'I06',
#   'KTYR',
#   'KUVA',
#   '9F1',
#   'KVHN',
#   'E52',
#   'F05',
#   'KVCT',
#   'KACT',
#   'KCNW',
#   'KPWG',
#   '73F',
#   'KWEA',
#   'F78',
#   'F06',
#   'KTXW',
#   'KARM',
#   '94R',
#   'T59',
#   'T29',
#   '5TX',
#   'KSPS',
#   'KCWC',
#   'F14',
#   '76F',
#   'KINK',
#   'T90',
#   'F51',
#   '77F',
#   '09R',
#   'T85',
#   'KAPY'],
#  'UT': ['U52',
#   'KBDG',
#   '66V',
#   'KBTF',
#   'KBMC',
#   'KBCE',
#   'KCDC',
#   'UT9',
#   'KDTA',
#   'U69',
#   '33U',
#   '1L7',
#   'KFOM',
#   'U07',
#   'U34',
#   'U96',
#   'KHVE',
#   'KHCR',
#   '69V',
#   '1L8',
#   'U13',
#   'KKNB',
#   '38U',
#   'KLGU',
#   '40U',
#   '41U',
#   'KMLF',
#   'KCNY',
#   'U64',
#   '42U',
#   'U14',
#   'KOGD',
#   'U55',
#   '1L9',
#   'KPUC',
#   'KPVU',
#   'KRIF',
#   '74V',
#   '44U',
#   'KSLC',
#   'U42',
#   'KSPK',
#   'KSGU',
#   'KTVY',
#   'KVEL',
#   'KENV'],
#  'VT': ['KMPV',
#   'KDDH',
#   'KBTV',
#   'KFSO',
#   '5B1',
#   'KCDA',
#   '6B0',
#   'KMVL',
#   'KEFK',
#   '2B9',
#   'KRUT',
#   'VT8',
#   'KVSF',
#   'B06',
#   '0B7',
#   '4V8'],
#  'VA': ['KVJI',
#   'KBCB',
#   'KBKT',
#   'KVBW',
#   '0V4',
#   '7W4',
#   'KCHO',
#   'KCXE',
#   'W63',
#   'W81',
#   'KCJR',
#   'KDAN',
#   'KPSK',
#   'KEMV',
#   'KFVX',
#   'W90',
#   'KFKN',
#   'KEZF',
#   'KFRR',
#   'KHLX',
#   'KGVE',
#   'KHSP',
#   '0VG',
#   'W31',
#   'KLVL',
#   'KJYO',
#   'KLKU',
#   'KLUA',
#   'KLYH',
#   'W24',
#   'KMKJ',
#   'KMTV',
#   'KMFV',
#   'W91',
#   '8W2',
#   'KPHF',
#   'KORF',
#   'KPVG',
#   'KCPK',
#   'KOMH',
#   'KPTB',
#   'W96',
#   'KJFZ',
#   'KRIC',
#   'KFCI',
#   'KOFP',
#   'KROA',
#   'W75',
#   'W78',
#   'KAVC',
#   'KRMN',
#   'KSHD',
#   'KSFQ',
#   'KTGI',
#   'KXSA',
#   'KAKQ',
#   'KHWY',
#   'W13',
#   '9VG',
#   'KFYJ',
#   'KJGG',
#   'KOKV',
#   'KLNP'],
#  'WA': ['74S',
#   'D69',
#   'KAWO',
#   'S50',
#   '4W0',
#   'W52',
#   'W58',
#   'KBLI',
#   'KPWT',
#   'S97',
#   'KBVS',
#   '1W1',
#   '8S2',
#   'KCLS',
#   'S10',
#   '9WA',
#   '1S9',
#   'C72',
#   'S93',
#   '2W1',
#   'S94',
#   '00W',
#   'S95',
#   '63S',
#   '3W5',
#   'S16',
#   '1S2',
#   '68S',
#   'KDEW',
#   'KESW',
#   'KORS',
#   '2W3',
#   '3W7',
#   'KELN',
#   'KEPH',
#   'KPAE',
#   'S18',
#   'KFHR',
#   'S20',
#   '21W',
#   'KHQM',
#   '7W1',
#   'S23',
#   'W09',
#   'KKLS',
#   'S36',
#   'W10',
#   '69S',
#   '27W',
#   '0S0',
#   'S31',
#   '38W',
#   '8W3',
#   'M94',
#   'W12',
#   '70S',
#   '09S',
#   'W16',
#   '39P',
#   'KMWH',
#   'W20',
#   'KOKH',
#   'W04',
#   '43D',
#   'S35',
#   'KOLM',
#   '44T',
#   'KOMK',
#   '0S7',
#   'S70',
#   '55S',
#   'KPSC',
#   '1RL',
#   'KCLM',
#   '0S9',
#   'S40',
#   'KPUW',
#   'KPLU',
#   'KUIL',
#   '80T',
#   'KRNT',
#   'R49',
#   'KRLD',
#   '4S6',
#   '33S',
#   '8W9',
#   '72S',
#   'KBFI',
#   'KSEA',
#   '11S',
#   'W28',
#   'KSHN',
#   '8W5',
#   'S88',
#   'S43',
#   '2S9',
#   '3B8',
#   'KGEG',
#   'KSFF',
#   '13W',
#   '16W',
#   '6S9',
#   '1S5',
#   'KTIW',
#   '73S',
#   'KTDO',
#   'W01',
#   '2S0',
#   'KVUO',
#   'W56',
#   '2S1',
#   'KALW',
#   '2S4',
#   '2S5',
#   'KEAT',
#   '14S',
#   '2S8',
#   '5W1',
#   'S52',
#   'W27',
#   'KYKM'],
#  'WV': ['70D',
#   'KBKW',
#   'W35',
#   'KBLF',
#   'W22',
#   'KCRW',
#   'KCKB',
#   'KEKN',
#   '4G7',
#   'KHTS',
#   'I41',
#   'KLWB',
#   '6L4',
#   'KMRB',
#   '12V',
#   'KMGW',
#   'KMPG',
#   '7G1',
#   'KPKB',
#   'W99',
#   '79D',
#   '9W3',
#   'I16',
#   '3I2',
#   'I18',
#   '3I4',
#   '6W0',
#   'KUSW',
#   '55I',
#   'KSXL',
#   '48I',
#   'KHLG',
#   'KEBD'],
#  'WI': ['54W',
#   'KAHH',
#   'KAIG',
#   'KATW',
#   'KASX',
#   'KDLL',
#   '9Y7',
#   '44C',
#   'KBCK',
#   'KOVS',
#   'KBDJ',
#   '3T3',
#   'C37',
#   '02C',
#   'KBUU',
#   '3CU',
#   '49C',
#   'C74',
#   'Y23',
#   '11Y',
#   'KCLI',
#   'Y55',
#   '3D1',
#   'KUBE',
#   'C59',
#   '5G4',
#   'KEGV',
#   '57C',
#   'KEAU',
#   '58C',
#   '60C',
#   '3D2',
#   'KFLD',
#   '61C',
#   '62C',
#   '63C',
#   'KGTG',
#   'KGRB',
#   'KHXF',
#   'KHYR',
#   '68C',
#   'Y77',
#   'KJVL',
#   'KUNU',
#   'KENW',
#   'KLSE',
#   '4R5',
#   'KRCX',
#   'C02',
#   '73C',
#   'KLNL',
#   'KLNR',
#   'KMSN',
#   '87Y',
#   'D25',
#   'KMTW',
#   'KMFI',
#   'KMDZ',
#   'KLUM',
#   'KRRL',
#   'C29',
#   'KMKE',
#   'KMWC',
#   'KMRJ',
#   'KARV',
#   'KEFT',
#   'KCWA',
#   'KDAF',
#   '79C',
#   'KVIQ',
#   '8D1',
#   '82C',
#   'KRNH',
#   'KOCQ',
#   'KOEO',
#   'KOSH',
#   '88C',
#   'KPKF',
#   'KPBH',
#   'KPVB',
#   'C47',
#   'KPDC',
#   '91C',
#   '5N2',
#   '92C',
#   'KRAC',
#   'C35',
#   'KRHI',
#   'KRPD',
#   '93C',
#   '94C',
#   '96C',
#   'KEZS',
#   'KSBM',
#   'KSSQ',
#   'W34',
#   'KRZN',
#   'KOLG',
#   'KCMY',
#   '1H9',
#   'KSTE',
#   'KSUE',
#   'C89',
#   'KSUW',
#   '7P5',
#   '40D',
#   'Y72',
#   'KTKV',
#   'W19',
#   'Y51',
#   '7V3',
#   '2P2',
#   'KRYV',
#   'KUES',
#   '6P3',
#   'KPCZ',
#   'KAUW',
#   'Y50',
#   'KETB',
#   '5Y3',
#   'W23',
#   'KISW',
#   '4D1'],
#  'WY': ['KAFO',
#   '46U',
#   'KBPI',
#   'KBYG',
#   'KCPR',
#   'KHAD',
#   'KCYS',
#   'KCOD',
#   'U06',
#   'U68',
#   'KDWX',
#   'KDGW',
#   'KDUB',
#   'KEVW',
#   'KFBR',
#   'KGCC',
#   '76V',
#   '48U',
#   'KGEY',
#   'KGUR',
#   'W43',
#   'KJAC',
#   'KEMM',
#   'KLND',
#   'KLAR',
#   'KLSK',
#   '80V',
#   'KECS',
#   '82V',
#   'KPNA',
#   'KPOY',
#   'KRWL',
#   'KRIW',
#   'KRKS',
#   'KSAA',
#   'KSHR',
#   '49U',
#   'KHSG',
#   'KTOR',
#   '83V',
#   'KEAN',
#   'KWRL']}

# %%
USdict = {}
count=1
for key in airport_dict.keys():
    for airport in airport_dict[key]:
        time.sleep(5)
        results = get_min_price(airport)
        USdict[airport] = results
        print('Done:',airport,results,count)
        count+=1
# Out:
# Done: 0J0 ('1000', '1000', 200) 1
# Done: 2A8 ('1000', '1000', 200) 2
# Done: KEET ('3.80', '4.15', 200) 3
# Done: 8A0 ('4.45', '4.10', 200) 4
# Done: KALX ('3.60', '4.10', 200) 5
# Done: KAIV ('1000', '1000', 200) 6
# Done: 79J ('2.99', '2.29', 200) 7
# Done: KANB ('3.79', '3.24', 200) 8
# Done: 1M3 ('1000', '1000', 200) 9
# Done: 26A ('1000', '1000', 200) 10
# Done: 0R1 ('1000', '1000', 200) 11
# Done: KAUO ('3.50', '3.30', 200) 12
# Done: 1R8 ('1000', '3.85', 200) 13
# Done: 5R7 ('1000', '1000', 200) 14
# Done: KEKY ('4.48', '4.59', 200) 15
# Done: KBHM ('4.83', '5.40', 200) 16
# Done: 12J ('4.78', '3.90', 200) 17
# Done: 09A ('1000', '1000', 200) 18
# Done: 61A ('1000', '1000', 200) 19
# Done: KPYP ('1000', '1000', 200) 20
# Done: 0A8 ('1000', '1000', 200) 21
# Done: 5R1 ('1000', '1000', 200) 22
# Done: 02A ('4.45', '3.45', 200) 23
# Done: 11A ('1000', '1000', 200) 24
# Done: 9A4 ('1000', '1000', 200) 25
# Done: 15A ('1000', '1000', 200) 26
# Done: KCMD ('3.50', '2.99', 200) 27
# Done: 4R9 ('1000', '1000', 200) 28
# Done: KDCU ('4.50', '4.30', 200) 29
# Done: KDYA ('4.20', '3.80', 200) 30
# Done: KDHN ('4.61', '4.31', 200) 31
# Done: 3M2 ('1000', '1000', 200) 32
# Done: 14J ('1000', '1000', 200) 33
# Done: KEDN ('3.27', '2.35', 200) 34
# Done: KEUF ('4.00', '4.30', 200) 35
# Done: KGZH ('3.25', '2.99', 200) 36
# Done: KCQF ('3.85', '3.50', 200) 37
# Done: M95 ('3.16', '1000', 200) 38
# Done: 0J4 ('5.85', '5.35', 200) 39
# Done: 5R4 ('1000', '1000', 200) 40
# Done: 4A9 ('4.00', '3.70', 200) 41
# Done: KGAD ('3.90', '4.00', 200) 42
# Done: 33J ('1000', '1000', 200) 43
# Done: 7A0 ('1000', '1000', 200) 44
# Done: KPRN ('1000', '1000', 200) 45
# Done: KJKA ('4.20', '4.04', 200) 46
# Done: 8A1 ('1000', '1000', 200) 47
# Done: 1M4 ('4.63', '4.81', 200) 48
# Done: KHAB ('3.10', '1000', 200) 49
# Done: 5M0 ('1000', '1000', 200) 50
# Done: M38 ('1000', '1000', 200) 51
# Done: 0J6 ('4.35', '2.75', 200) 52
# Done: KHSV ('4.50', '4.13', 200) 53
# Done: KMDQ ('4.58', '4.13', 200) 54
# Done: 3M5 ('1000', '1000', 200) 55
# Done: 4R3 ('1000', '1000', 200) 56
# Done: KJFX ('3.99', '4.29', 200) 57
# Done: 7A3 ('1000', '1000', 200) 58
# Done: 04A ('1000', '1000', 200) 59
# Done: A08 ('4.23', '3.50', 200) 60
# Done: KMOB ('6.18', '5.41', 200) 61
# Done: KBFM ('5.35', '5.77', 200) 62
# Done: KMVC ('1000', '3.62', 200) 63
# Done: KMGM ('5.15', '4.90', 200) 64
# Done: KMSL ('3.75', '3.95', 200) 65
# Done: 20A ('1000', '1000', 200) 66
# Done: 71J ('3.26', '3.25', 200) 67
# Done: KPLR ('3.60', '3.60', 200) 68
# Done: 1A9 ('3.20', '2.74', 200) 69
# Done: 3M8 ('1000', '1000', 200) 70
# Done: 7A5 ('1000', '1000', 200) 71
# Done: M22 ('1000', '1000', 200) 72
# Done: 1A4 ('1000', '1000', 200) 73
# Done: 4A6 ('3.90', '3.45', 200) 74
# Done: KSEM ('3.20', '2.74', 200) 75
# Done: 2R5 ('1000', '1000', 200) 76
# Done: 7A6 ('1000', '1000', 200) 77
# Done: KSCD ('3.97', '1000', 200) 78
# Done: KASN ('1000', '1000', 503) 79
# Done: KTOI ('1000', '1000', 503) 80
# Done: KTCL ('1000', '1000', 503) 81
# Done: 06A ('1000', '1000', 503) 82
# Done: 07A ('1000', '1000', 503) 83
# Done: M55 ('1000', '1000', 503) 84
# Done: 08A ('1000', '1000', 503) 85
# Done: PADK ('1000', '1000', 503) 86
# Done: PAKH ('1000', '1000', 503) 87
# Done: Z13 ('1000', '1000', 503) 88
# Done: PFAK ('1000', '1000', 503) 89
# Done: PAUT ('1000', '1000', 503) 90
# Done: PAUK ('1000', '1000', 503) 91
# Done: 5A8 ('1000', '1000', 503) 92
# Done: Z25 ('1000', '1000', 503) 93
# Done: PFAL ('1000', '1000', 503) 94
# Done: PAFM ('1000', '1000', 503) 95
# Done: 80A ('1000', '1000', 503) 96
# Done: PAKP ('1000', '1000', 503) 97
# Done: PANC ('1000', '1000', 503) 98
# Done: PAMR ('1000', '1000', 503) 99
# Done: PALH ('1000', '1000', 503) 100
# Done: A13 ('1000', '1000', 503) 101
# Done: PANI ('1000', '1000', 503) 102
# Done: PANV ('1000', '1000', 503) 103
# Done: PARC ('1000', '1000', 503) 104
# Done: PAAK ('1000', '1000', 503) 105
# Done: 4A2 ('1000', '1000', 503) 106
# Done: PATQ ('1000', '1000', 503) 107
# Done: PABR ('1000', '1000', 503) 108
# Done: PABA ('1000', '1000', 503) 109
# Done: Z47 ('1000', '1000', 503) 110
# Done: Z48 ('1000', '1000', 503) 111
# Done: Z52 ('1000', '1000', 503) 112
# Done: PAWB ('1000', '1000', 503) 113
# Done: PABE ('1000', '1000', 503) 114
# Done: PABT ('1000', '1000', 503) 115
# Done: PAGQ ('1000', '1000', 503) 116
# Done: Z91 ('1000', '1000', 503) 117
# Done: PABV ('1000', '1000', 503) 118
# Done: 5BK ('1000', '1000', 503) 119
# Done: BYA ('1000', '1000', 503) 120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-148-c2ff71d43425> in <module>
#       3 for key in airport_dict.keys():
#       4     for airport in airport_dict[key]:
# ----> 5         time.sleep(5)
#       6         results = get_min_price(airport)
#       7         USdict[airport] = results
#
# KeyboardInterrupt:

# %%
isDone = False
while !isDone:
    print('Trying Again')
    if len(USdict)>4759:
        isDone = True
    for key in USdict.keys():
        if USdict[key][2]=200:
            continue
        else:
# Out:
# {'0J0': ('1000', '1000', 200),
#  '2A8': ('1000', '1000', 200),
#  'KEET': ('3.80', '4.15', 200),
#  '8A0': ('4.45', '4.10', 200),
#  'KALX': ('3.60', '4.10', 200),
#  'KAIV': ('1000', '1000', 200),
#  '79J': ('2.99', '2.29', 200),
#  'KANB': ('3.79', '3.24', 200),
#  '1M3': ('1000', '1000', 200),
#  '26A': ('1000', '1000', 200),
#  '0R1': ('1000', '1000', 200),
#  'KAUO': ('3.50', '3.30', 200),
#  '1R8': ('1000', '3.85', 200),
#  '5R7': ('1000', '1000', 200),
#  'KEKY': ('4.48', '4.59', 200),
#  'KBHM': ('4.83', '5.40', 200),
#  '12J': ('4.78', '3.90', 200),
#  '09A': ('1000', '1000', 200),
#  '61A': ('1000', '1000', 200),
#  'KPYP': ('1000', '1000', 200),
#  '0A8': ('1000', '1000', 200),
#  '5R1': ('1000', '1000', 200),
#  '02A': ('4.45', '3.45', 200),
#  '11A': ('1000', '1000', 200),
#  '9A4': ('1000', '1000', 200),
#  '15A': ('1000', '1000', 200),
#  'KCMD': ('3.50', '2.99', 200),
#  '4R9': ('1000', '1000', 200),
#  'KDCU': ('4.50', '4.30', 200),
#  'KDYA': ('4.20', '3.80', 200),
#  'KDHN': ('4.61', '4.31', 200),
#  '3M2': ('1000', '1000', 200),
#  '14J': ('1000', '1000', 200),
#  'KEDN': ('3.27', '2.35', 200),
#  'KEUF': ('4.00', '4.30', 200),
#  'KGZH': ('3.25', '2.99', 200),
#  'KCQF': ('3.85', '3.50', 200),
#  'M95': ('3.16', '1000', 200),
#  '0J4': ('5.85', '5.35', 200),
#  '5R4': ('1000', '1000', 200),
#  '4A9': ('4.00', '3.70', 200),
#  'KGAD': ('3.90', '4.00', 200),
#  '33J': ('1000', '1000', 200),
#  '7A0': ('1000', '1000', 200),
#  'KPRN': ('1000', '1000', 200),
#  'KJKA': ('4.20', '4.04', 200),
#  '8A1': ('1000', '1000', 200),
#  '1M4': ('4.63', '4.81', 200),
#  'KHAB': ('3.10', '1000', 200),
#  '5M0': ('1000', '1000', 200),
#  'M38': ('1000', '1000', 200),
#  '0J6': ('4.35', '2.75', 200),
#  'KHSV': ('4.50', '4.13', 200),
#  'KMDQ': ('4.58', '4.13', 200),
#  '3M5': ('1000', '1000', 200),
#  '4R3': ('1000', '1000', 200),
#  'KJFX': ('3.99', '4.29', 200),
#  '7A3': ('1000', '1000', 200),
#  '04A': ('1000', '1000', 200),
#  'A08': ('4.23', '3.50', 200),
#  'KMOB': ('6.18', '5.41', 200),
#  'KBFM': ('5.35', '5.77', 200),
#  'KMVC': ('1000', '3.62', 200),
#  'KMGM': ('5.15', '4.90', 200),
#  'KMSL': ('3.75', '3.95', 200),
#  '20A': ('1000', '1000', 200),
#  '71J': ('3.26', '3.25', 200),
#  'KPLR': ('3.60', '3.60', 200),
#  '1A9': ('3.20', '2.74', 200),
#  '3M8': ('1000', '1000', 200),
#  '7A5': ('1000', '1000', 200),
#  'M22': ('1000', '1000', 200),
#  '1A4': ('1000', '1000', 200),
#  '4A6': ('3.90', '3.45', 200),
#  'KSEM': ('3.20', '2.74', 200),
#  '2R5': ('1000', '1000', 200),
#  '7A6': ('1000', '1000', 200),
#  'KSCD': ('3.97', '1000', 200),
#  'KASN': ('1000', '1000', 503),
#  'KTOI': ('1000', '1000', 503),
#  'KTCL': ('1000', '1000', 503),
#  '06A': ('1000', '1000', 503),
#  '07A': ('1000', '1000', 503),
#  'M55': ('1000', '1000', 503),
#  '08A': ('1000', '1000', 503),
#  'PADK': ('1000', '1000', 503),
#  'PAKH': ('1000', '1000', 503),
#  'Z13': ('1000', '1000', 503),
#  'PFAK': ('1000', '1000', 503),
#  'PAUT': ('1000', '1000', 503),
#  'PAUK': ('1000', '1000', 503),
#  '5A8': ('1000', '1000', 503),
#  'Z25': ('1000', '1000', 503),
#  'PFAL': ('1000', '1000', 503),
#  'PAFM': ('1000', '1000', 503),
#  '80A': ('1000', '1000', 503),
#  'PAKP': ('1000', '1000', 503),
#  'PANC': ('1000', '1000', 503),
#  'PAMR': ('1000', '1000', 503),
#  'PALH': ('1000', '1000', 503),
#  'A13': ('1000', '1000', 503),
#  'PANI': ('1000', '1000', 503),
#  'PANV': ('1000', '1000', 503),
#  'PARC': ('1000', '1000', 503),
#  'PAAK': ('1000', '1000', 503),
#  '4A2': ('1000', '1000', 503),
#  'PATQ': ('1000', '1000', 503),
#  'PABR': ('1000', '1000', 503),
#  'PABA': ('1000', '1000', 503),
#  'Z47': ('1000', '1000', 503),
#  'Z48': ('1000', '1000', 503),
#  'Z52': ('1000', '1000', 503),
#  'PAWB': ('1000', '1000', 503),
#  'PABE': ('1000', '1000', 503),
#  'PABT': ('1000', '1000', 503),
#  'PAGQ': ('1000', '1000', 503),
#  'Z91': ('1000', '1000', 503),
#  'PABV': ('1000', '1000', 503),
#  '5BK': ('1000', '1000', 503),
#  'BYA': ('1000', '1000', 503)}

# %%
len(airport_dict)
# Out:
# 51
